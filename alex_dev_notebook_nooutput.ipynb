# %% [markdown]
# # W207 Final Project - Facial Keypoint Recognition
# #### Alex Carite | Oscar Linares | Greg Rosen | Shehzad Shahbuddin

# %%
# dependencies
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
from sklearn.datasets import fetch_openml
from sklearn.metrics import classification_report, accuracy_score, RMSE
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.semi_supervised import LabelPropagation, LabelSpreading

import time
import os.path
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import matplotlib.pyplot as plt
import cv2
from random import randrange
from math import sin, cos, pi
# %matplotlib inline

from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, Activation, Dropout, Flatten, GlobalAveragePooling2D, LeakyReLU, BatchNormalization
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.applications import ResNet50, ResNet50V2
from tensorflow.keras.applications.efficientnet import EfficientNetB7, EfficientNetB0
from tensorflow.keras.applications.efficientnet_v2 import EfficientNetV2B3


np.random.seed(0)
print ("OK")
import tensorflow as tf
print("Tensorflow version", tf.__version__)
# Out:
# OK
# Tensorflow version 2.8.0

# %% [markdown]
# ### Load Data

# %%
#Checking to see if the train/test csv are loaded, if not, unzip from dir
if (os.path.exists('training.csv') == False):
    # !unzip training.zip
else:
    print('training data already unzipped')

if (os.path.exists('test.csv') == False):
    # !unzip test.zip
else:
    print('test data already unzipped')
# Out:
# training data already unzipped
# test data already unzipped

# %%
# load data
train = pd.read_csv('training.csv')
test = pd.read_csv('test.csv')
print(train.shape)
print(test.shape)
# Out:
# (7049, 31)
# (1783, 2)

# %% [markdown]
# # Need to clean up a few NA's in our set

# %%
# helper functions for data shapes
def two_dim(image):
    'takes in an image vector of 9,216 pixels and makes it into a 96x96 shape'
    return np.array(image.split(' '), dtype=int).reshape(96, 96)

def make_array(image):
    return np.array(image.split(' '), dtype=int)

# %%
# transform all data
X = np.array([two_dim(train.Image[i]) for i in range(len(train))])
# X_tmp = X_tmp / 255.0
# X = np.array([make_array(train.Image[i]) for i in range(len(train))])
X = X / 255.0
Y = np.array([train.drop('Image', axis = 1).iloc[i] for i in range(len(train))])

#Need to make X_test and Y_test (will we have a Y_test? I think that may be handled in Kaggle)

shuffle = np.random.permutation(np.arange(X.shape[0]))
X, Y = X[shuffle], Y[shuffle]
train_data, train_labels = X[:5000], Y[:5000]
mini_train_data, mini_train_labels = X[:1000], Y[:1000]
dev_data, dev_labels = X[5000:], Y[5000:]
numFeatures = train_data[1].size
numTrainExamples = train_data.shape[0]
numMiniExamples = mini_train_data.shape[0]
numDevExamples = dev_data.shape[0]
# numTestExamples = test_data.shape[0]
print(f'Train examples {numTrainExamples}')
print(f'Train features {numFeatures}')
print(f'mini_Train examples {numMiniExamples}')
print(f'Dev examples {numDevExamples}')
# print(f'Test examples {numTestExamples}')
# Out:
# Train examples 5000
# Train features 9216
# mini_Train examples 1000
# Dev examples 2049

# %%
# view missing values
import missingno as msno
fig, ax = plt.subplots()
msno.bar(train)
ax.set_title("Missing Values", fontsize = 30, pad = 20)
ax.set_xlabel("Feature", fontsize = 25, labelpad = 20)
ax.set_ylabel("Fill Rate", fontsize = 25, labelpad = 20)
plt.show()

# %%
# EDA see how many na's for each column in the training dataset
train.isna().sum()/len(train)*100
# Out:
# left_eye_center_x             0.141864
# left_eye_center_y             0.141864
# right_eye_center_x            0.184423
# right_eye_center_y            0.184423
# left_eye_inner_corner_x      67.782664
# left_eye_inner_corner_y      67.782664
# left_eye_outer_corner_x      67.839410
# left_eye_outer_corner_y      67.839410
# right_eye_inner_corner_x     67.825223
# right_eye_inner_corner_y     67.825223
# right_eye_outer_corner_x     67.825223
# right_eye_outer_corner_y     67.825223
# left_eyebrow_inner_end_x     67.796851
# left_eyebrow_inner_end_y     67.796851
# left_eyebrow_outer_end_x     68.435239
# left_eyebrow_outer_end_y     68.435239
# right_eyebrow_inner_end_x    67.796851
# right_eyebrow_inner_end_y    67.796851
# right_eyebrow_outer_end_x    68.279189
# right_eyebrow_outer_end_y    68.279189
# nose_tip_x                    0.000000
# nose_tip_y                    0.000000
# mouth_left_corner_x          67.811037
# mouth_left_corner_y          67.811037
# mouth_right_corner_x         67.796851
# mouth_right_corner_y         67.796851
# mouth_center_top_lip_x       67.725919
# mouth_center_top_lip_y       67.725919
# mouth_center_bottom_lip_x     0.468152
# mouth_center_bottom_lip_y     0.468152
# Image                         0.000000
# dtype: float64

# %% [markdown]
# ## EDA (Removing Missing Values)
# We lose 70% of the dataset when removing NAs

# %%
#Checking for duplicates 
train.duplicated(subset = ['Image'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7044     True
# 7045     True
# 7046    False
# 7047    False
# 7048     True
# Length: 7049, dtype: bool

# %%
#drop NAs from train and split into training and dev
train_noNA_temp = train.dropna()
dev_set = train_noNA_temp[:500]
train_noNA = train_noNA_temp[500:]

#From the complete train set, drop the rows which will be included in the dev set
cond = train['Image'].isin(dev_set['Image'])
train.drop(train[cond].index, inplace = True)

#Create a ffill set based off the training data 
train_ffill = train.fillna(method='ffill')

def load_images(image_data):
    images = []
    for idx, sample in image_data.iterrows():
        image = np.array(sample['Image'].split(' '), dtype=int)
        image = np.reshape(image, (96,96,1))
        images.append(image)
    images = np.array(images)/255.
    return images

def load_labels(label_data):
    label_data = label_data.drop(['Image'], axis=1)
    label_features = []
    for idx, features in label_data.iterrows():
        label_features.append(features)
    label_features = np.array(label_features, dtype=float)
    return label_features


#Set of full data with ffill for missing labels
train_data_ffill  = load_images(train_ffill)
train_labels_ffill = load_labels(train_ffill)


#Dataset with only no NA rows
train_data_noNA  = load_images(train_noNA)
train_labels_noNA = load_labels(train_noNA)


#Dev set for testing 
dev_data = load_images(dev_set)
dev_labels = load_labels(dev_set)


#Test images for Kaggle competition 
test_images = load_images(test)

# %%
print(train_noNA_temp.shape, dev_set.shape, train_noNA.shape, train.shape, train_ffill.shape)
# Out:
# (2140, 31) (500, 31) (1640, 31) (6549, 31) (6549, 31)

# %%
#Create function for showing images
def show_images(data, labels, num_examples=3):
  
  #transform data  into 2D matrix
  X2D = np.reshape(data, (-1, 96, 96))

  num = num_examples * 3
  count = 0

  #create a figure 
  fig, axes = plt.subplots(num_examples, 3, figsize = (9.6, 9.6))


  #iterate across the row of images and display one image in each of the num_examples boxes
  for n in range(num):
      ax = axes[count//num_examples, count%num_examples]
      rand = randrange(0, len(data))
      ax.imshow(X2D[rand], cmap = 'gray')
      count += 1
      for loc in range(0, len(labels[n]), 2):
          ax.plot(labels[rand][loc], labels[rand][loc+1], '*r')
      
  plt.tight_layout()
  plt.show()

# %% [markdown]
# View some images with labeled points.

# %%
#explore some of the images in the training data
show_images(train_data, train_labels)

# %% [markdown]
# View images without missing values.

# %%
#Same analysis as above but with the noNA dataset - notice the how all the features are marked on the face
show_images(train_data_noNA, train_labels_noNA)

# %% [markdown]
# Note that images with missing values are not as accurate as fully filled records, even for the values it has filled.

# %%
#continue EDA, see distribution of all coordinates in train data except the "Image" column
train.hist(bins = 30, figsize=(15,15))
plt.show()

# %%
#take a look at removing outliers
# train_outliers  = train[((train['left_eye_inner_corner_x'] - train['left_eye_inner_corner_x'].mean()) / train['left_eye_inner_corner_x'].std()).abs() < 3]
# train_outliers = train[train.apply(lambda x: np.abs(x - x.mean()) / x.std() < 3).all(axis=1)]
# train_outliers.hist(bins = 30, figsize=(15,15))
# plt.show()

#create df for noNA data to do the same analysis as above
# tempdf = pd.DataFrame(train_labels_noNA)
# tempdf.hist(bins = 30, figsize=(15,15))
# plt.show()

# %% [markdown]
# Use the next two cells if you want to explore the dev data to make sure it's clean as well

# %%
#tempdf = pd.DataFrame(dev_labels_noNA)

# %%
#tempdf.hist(bins = 30, figsize=(15,15))

# %%
#Confirm size of the datasets
print(train_data_noNA.shape)
print(train_labels_noNA.shape)
print(dev_data.shape)
print(dev_labels.shape)
# Out:
# (1640, 96, 96, 1)
# (1640, 30)
# (500, 96, 96, 1)
# (500, 30)

# %% [markdown]
# ## Augmenting the Data

# %%
# define image augmentation functions
def rotate_augmentation(images, keypoints, angles):
    rotated_images = []
    rotated_keypoints = []
    for angle in angles:    # Rotation augmentation for a list of angle values
        for angle in [angle,-angle]:
            rotation_matrix = cv2.getRotationMatrix2D((48,48), angle, 1.0)
            angle_rad = -angle*pi/180.     # Obtain angle in radians from angle in degrees (notice negative sign for change in clockwise vs anti-clockwise directions from conventional rotation to cv2's image rotation)
            # rotate images
            for image in images:
                rotated_image = cv2.warpAffine(image, rotation_matrix, (96,96), flags=cv2.INTER_CUBIC)
                rotated_images.append(rotated_image)
            rotated_images_reshaped = np.reshape(rotated_images, (-1,96,96,1))
            # rotate keypoints
            for keypoint in keypoints:
                rotated_keypoint = keypoint - 48.    # Subtract the middle value of the image dimension
                for idx in range(0, len(rotated_keypoint), 2):
                    # https://in.mathworks.com/matlabcentral/answers/93554-how-can-i-rotate-a-set-of-points-in-a-plane-by-a-certain-angle-about-an-arbitrary-point
                    rotated_keypoint[idx] = rotated_keypoint[idx]*cos(angle_rad)-rotated_keypoint[idx+1]*sin(angle_rad)
                    rotated_keypoint[idx+1] = rotated_keypoint[idx]*sin(angle_rad)+rotated_keypoint[idx+1]*cos(angle_rad)
                rotated_keypoint += 48.   # Add the earlier subtracted value
                rotated_keypoints.append(rotated_keypoint)
            rotated_keypoints_reshaped = np.reshape(rotated_keypoints, (-1, 30))
    return rotated_images_reshaped, rotated_keypoints_reshaped

def alter_brightness(images, keypoints, increase_factor=1.2, decrease_factor=0.6):
    altered_brightness_images = []
    inc_brightness_images = np.clip(images*increase_factor, 0.0, 1.0)    # Increased brightness & clip any values outside the range of [-1,1]
    dec_brightness_images = np.clip(images*decrease_factor, 0.0, 1.0)    # Decreased brightness & clip any values outside the range of [-1,1]
    altered_brightness_images.extend(inc_brightness_images)
    altered_brightness_images.extend(dec_brightness_images)
    altered_brightness_images_reshaped = np.reshape(altered_brightness_images, (-1,96,96,1))
    altered_brightness_keypoints_reshaped = np.reshape(np.concatenate((keypoints, keypoints)), (-1, 30))
    return altered_brightness_images_reshaped, altered_brightness_keypoints_reshaped

def shift_images(images, keypoints, pixel_shifts):
    shifted_images = []
    shifted_keypoints = []
    for shift in pixel_shifts:    # Augmenting over several pixel shift values
        for (shift_x,shift_y) in [(-shift,-shift),(-shift,shift),(shift,-shift),(shift,shift)]:
            shift_matrix = np.float32([[1,0,shift_x],[0,1,shift_y]])
            for image, keypoint in zip(images, keypoints):
                shifted_image = cv2.warpAffine(image, shift_matrix, (96,96), flags=cv2.INTER_CUBIC)
                shifted_keypoint = np.array([(point+shift_x) if idx%2==0 else (point+shift_y) for idx, point in enumerate(keypoint)])
                if np.all(0.0<shifted_keypoint) and np.all(shifted_keypoint<96.0):
                    shifted_images.append(shifted_image.reshape(96,96,1))
                    shifted_keypoints.append(shifted_keypoint)
    shifted_images_reshaped = np.reshape(shifted_images, (-1,96,96,1))
    shifted_keypoints = np.clip(shifted_keypoints,0.0,96.0)
    shifted_keypoints_reshaped = np.reshape(shifted_keypoints, (-1, 30))
    return shifted_images_reshaped, shifted_keypoints_reshaped

def add_random_noise(images, keypoints, noise_factor=0.008):
    noisy_images = []
    for image in images:
        noisy_image = cv2.add(image, noise_factor*np.random.randn(96,96,1))    # Adding random normal noise to the input image & clip the resulting noisy image between [-1,1]
        noisy_images.append(noisy_image.reshape(96,96,1))
    noisy_images_reshaped = np.reshape(noisy_images, (-1,96,96,1))
    return noisy_images_reshaped, keypoints

def guassian_blur(images, keypoints, kernel=(5,5)):
    blurred_images = []
    for image in images:
        dst = cv2.GaussianBlur(image, kernel, cv2.BORDER_DEFAULT)
        blurred_image = dst.reshape(96,96,1)
        blurred_images.append(blurred_image)
    blurred_images_reshaped = np.reshape(blurred_images, (-1,96,96,1))
    return blurred_images_reshaped, keypoints

# %%
# rotate images and keypoints
train_data_rotated, train_labels_rotated = rotate_augmentation(train_data_noNA, train_labels_noNA, [12])

# alter brightness
train_data_brightness, train_labels_brightness = alter_brightness(
                                                        train_data_noNA,
                                                        train_labels_noNA,
                                                        increase_factor=1.2,
                                                        decrease_factor=0.6
                                                    )

# shift images and keypoints
train_data_shifted, train_labels_shifted = shift_images(train_data_noNA, train_labels_noNA, [12])

# add random noise
train_data_noise, train_labels_noise = add_random_noise(train_data_noNA, train_labels_noNA, 0.03)

# apply gaussian blur
train_data_blurred, train_labels_blurred = guassian_blur(train_data_noNA, train_labels_noNA, kernel=(5,5))

# %%
# merge all augmented data
train_data_aug = np.concatenate(
    (train_data_noNA, train_data_rotated, train_data_shifted, train_data_brightness, train_data_noise, train_data_blurred)
)

train_labels_aug = np.concatenate(
    (train_labels_noNA, train_labels_rotated, train_labels_shifted, train_labels_brightness, train_labels_noise, train_labels_blurred)
)

print(train_data_aug.shape)
print(train_labels_aug.shape)
# Out:
# (16267, 96, 96, 1)
# (16267, 30)

# %% [markdown]
# # Modeling on the data

# %%
# shape tuples for reshaping the data for model
train_reshape = (5000, 9216)
train_noNA_reshape = (1200, 9216)
dev_reshape = (2049, 9216)
dev_noNA_reshape = (940, 9216)
label_reshape= (-1, 30)

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
earlyStopping = EarlyStopping(monitor='loss', patience=30, mode='min',
                             baseline=None)

rlp = ReduceLROnPlateau(monitor='val_loss', factor=0.7, patience=5, min_lr=1e-15, mode='min', verbose=1)

# %% [markdown]
# ### Baseline

# %%
# baseline model with NAs
model_base = Sequential()
# model.add(Dense(30, input_dim=9216, activation='sigmoid'))
# model.add(Dense(30, input_dim=30, activation='sigmoid'))
model_base.add(Dense(units=30, input_dim=9216, activation='softmax'))

sgd = optimizers.SGD(lr=0.01)
model_base.compile(optimizer=sgd, loss='categorical_crossentropy', metrics=['accuracy'])
start_time = time.time()
history = model_base.fit(train_data.reshape(train_reshape), train_labels, shuffle=False, batch_size=1, verbose=0, epochs=10) 
print ('Train time = %.2f' %(time.time() - start_time))
score_base = model_base.evaluate(dev_data.reshape(dev_reshape), dev_labels, verbose=0) 
print('Test score:', score_base[0]) 
print('Test accuracy:', score_base[1])

# %% [markdown]
# ### Missing Value Records Removed

# %%
# No NA model
model_NN_noNA1 = Sequential()
# model_NN_noNA1.add(Dense(30, input_dim=9216, activation='sigmoid'))
# model_NN_noNA1.add(Dense(30, input_dim=30, activation='sigmoid'))
model_NN_noNA1.add(Dense(units=30, input_dim=9216, activation='softmax'))

sgd = optimizers.SGD(lr=0.01)
model_NN_noNA1.compile(optimizer=sgd, loss='categorical_crossentropy', metrics=['accuracy'])
start_time = time.time()
history = model_NN_noNA1.fit(train_data_noNA.reshape(train_noNA_reshape), train_labels_noNA, shuffle=False, batch_size=1, verbose=0, epochs=10) 
print ('Train time = %.2f' %(time.time() - start_time))
score_NN_noNA1 = model_NN_noNA1.evaluate(dev_data_noNA.reshape(dev_noNA_reshape), dev_labels_noNA, verbose=0) 
print('Test score:', score_NN_noNA1[0]) 
print('Test accuracy:', score_NN_noNA1[1])

# %% [markdown]
# Because baseline performance is higher on the missing-value-removed model, and the filled values on the missing-value records are inaccurate, we will proceed with iterating on the no-na model (or maybe we will add an additional label that specifies which records had imputed values) so the model can take that into consideration.

# %% [markdown]
# ### Convolutional Model Baseline Attempt (FFILL)

# %%
model_CNN_ffill1 = Sequential() 
model_CNN_ffill1.add(Conv2D(64, kernel_size=(3, 3),activation='relu',input_shape=(96, 96, 1)))
model_CNN_ffill1.add(MaxPooling2D(pool_size=(2, 2)))
model_CNN_ffill1.add(Dropout(0.5))
model_CNN_ffill1.add(Flatten())
model_CNN_ffill1.add(Dense(96))
model_CNN_ffill1.add(BatchNormalization())
model_CNN_ffill1.add(Activation('relu'))
model_CNN_ffill1.add(Dense(30))
 

# model_CNN_ffill1.summary()

model_CNN_ffill1.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])
history_CNN_ffill1 = model_CNN_ffill1.fit(train_data_ffill, train_labels_ffill, batch_size=64, epochs=100, validation_data=(dev_data, dev_labels), shuffle = True, callbacks=[earlyStopping, rlp])
score_CNN_ffill1 = model_CNN_ffill1.evaluate(dev_data, dev_labels, verbose=0)
print('Test score:', score_CNN_ffill1[0]) 
print('Test accuracy:', score_CNN_ffill1[1])
# Out:
# Epoch 1/100
# 103/103 [==============================] - 24s 224ms/step - loss: nan - accuracy: 0.0014 - val_loss: nan - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 2/100
# 103/103 [==============================] - 23s 223ms/step - loss: nan - accuracy: 1.5270e-04 - val_loss: nan - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 3/100
# 103/103 [==============================] - 23s 222ms/step - loss: nan - accuracy: 1.5270e-04 - val_loss: nan - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 4/100
# 103/103 [==============================] - 23s 223ms/step - loss: nan - accuracy: 0.1095 - val_loss: nan - val_accuracy: 0.1660 - lr: 0.0010
# Epoch 5/100
# 103/103 [==============================] - ETA: 0s - loss: nan - accuracy: 0.3991
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0007000000332482159.
# 103/103 [==============================] - 23s 223ms/step - loss: nan - accuracy: 0.3991 - val_loss: nan - val_accuracy: 0.1660 - lr: 0.0010
# Epoch 6/100
# 103/103 [==============================] - 23s 223ms/step - loss: nan - accuracy: 0.6564 - val_loss: nan - val_accuracy: 0.1660 - lr: 7.0000e-04
# Epoch 7/100
# 103/103 [==============================] - 23s 223ms/step - loss: nan - accuracy: 0.6564 - val_loss: nan - val_accuracy: 0.1660 - lr: 7.0000e-04
# Epoch 8/100
# 103/103 [==============================] - 23s 223ms/step - loss: nan - accuracy: 0.6564 - val_loss: nan - val_accuracy: 0.1660 - lr: 7.0000e-04
# Epoch 9/100
# 103/103 [==============================] - 23s 222ms/step - loss: nan - accuracy: 0.6564 - val_loss: nan - val_accuracy: 0.1660 - lr: 7.0000e-04
# Epoch 10/100
# 103/103 [==============================] - ETA: 0s - loss: nan - accuracy: 0.6564
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0004900000232737511.
# 103/103 [==============================] - 23s 223ms/step - loss: nan - accuracy: 0.6564 - val_loss: nan - val_accuracy: 0.1660 - lr: 7.0000e-04
# Epoch 11/100
# 103/103 [==============================] - 23s 223ms/step - loss: nan - accuracy: 0.6564 - val_loss: nan - val_accuracy: 0.1660 - lr: 4.9000e-04
# Epoch 12/100
# 103/103 [==============================] - 23s 223ms/step - loss: nan - accuracy: 0.6564 - val_loss: nan - val_accuracy: 0.1660 - lr: 4.9000e-04
# Epoch 13/100
# 103/103 [==============================] - 23s 224ms/step - loss: nan - accuracy: 0.6564 - val_loss: nan - val_accuracy: 0.1660 - lr: 4.9000e-04
# Epoch 14/100
# 103/103 [==============================] - 23s 222ms/step - loss: nan - accuracy: 0.6564 - val_loss: nan - val_accuracy: 0.1660 - lr: 4.9000e-04
# Epoch 15/100
# 103/103 [==============================] - ETA: 0s - loss: nan - accuracy: 0.6564
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.00034300000406801696.
# 103/103 [==============================] - 23s 222ms/step - loss: nan - accuracy: 0.6564 - val_loss: nan - val_accuracy: 0.1660 - lr: 4.9000e-04
# Epoch 16/100
# 103/103 [==============================] - 23s 222ms/step - loss: nan - accuracy: 0.6564 - val_loss: nan - val_accuracy: 0.1660 - lr: 3.4300e-04
# Epoch 17/100
# 103/103 [==============================] - 23s 222ms/step - loss: nan - accuracy: 0.6564 - val_loss: nan - val_accuracy: 0.1660 - lr: 3.4300e-04
# Epoch 18/100
# 103/103 [==============================] - 23s 223ms/step - loss: nan - accuracy: 0.6564 - val_loss: nan - val_accuracy: 0.1660 - lr: 3.4300e-04
# Epoch 19/100
# 103/103 [==============================] - 23s 222ms/step - loss: nan - accuracy: 0.6564 - val_loss: nan - val_accuracy: 0.1660 - lr: 3.4300e-04
# Epoch 20/100
# 103/103 [==============================] - ETA: 0s - loss: nan - accuracy: 0.6564
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.00024009999469853935.
# 103/103 [==============================] - 23s 223ms/step - loss: nan - accuracy: 0.6564 - val_loss: nan - val_accuracy: 0.1660 - lr: 3.4300e-04
# Epoch 21/100
# 103/103 [==============================] - 23s 223ms/step - loss: nan - accuracy: 0.6564 - val_loss: nan - val_accuracy: 0.1660 - lr: 2.4010e-04
# Epoch 22/100
# 103/103 [==============================] - 23s 222ms/step - loss: nan - accuracy: 0.6564 - val_loss: nan - val_accuracy: 0.1660 - lr: 2.4010e-04
# Epoch 23/100
# 103/103 [==============================] - 23s 222ms/step - loss: nan - accuracy: 0.6564 - val_loss: nan - val_accuracy: 0.1660 - lr: 2.4010e-04
# Epoch 24/100
# 103/103 [==============================] - 23s 223ms/step - loss: nan - accuracy: 0.6564 - val_loss: nan - val_accuracy: 0.1660 - lr: 2.4010e-04
# Epoch 25/100
# 103/103 [==============================] - ETA: 0s - loss: nan - accuracy: 0.6564
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.00016806999628897755.
# 103/103 [==============================] - 23s 223ms/step - loss: nan - accuracy: 0.6564 - val_loss: nan - val_accuracy: 0.1660 - lr: 2.4010e-04
# Epoch 26/100
# 103/103 [==============================] - 23s 223ms/step - loss: nan - accuracy: 0.6564 - val_loss: nan - val_accuracy: 0.1660 - lr: 1.6807e-04
# Epoch 27/100
# 103/103 [==============================] - 49s 479ms/step - loss: nan - accuracy: 0.6564 - val_loss: nan - val_accuracy: 0.1660 - lr: 1.6807e-04
# Epoch 28/100
# 103/103 [==============================] - 23s 224ms/step - loss: nan - accuracy: 0.6564 - val_loss: nan - val_accuracy: 0.1660 - lr: 1.6807e-04
# Epoch 29/100
# 103/103 [==============================] - 23s 228ms/step - loss: nan - accuracy: 0.6564 - val_loss: nan - val_accuracy: 0.1660 - lr: 1.6807e-04
# Epoch 30/100
# 103/103 [==============================] - ETA: 0s - loss: nan - accuracy: 0.6564
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.00011764899536501615.
# 103/103 [==============================] - 28s 268ms/step - loss: nan - accuracy: 0.6564 - val_loss: nan - val_accuracy: 0.1660 - lr: 1.6807e-04
# Test score: nan
# Test accuracy: 0.16600000858306885

# %%
sns.set_style('darkgrid')

fig, ax = plt.subplots(2, 1, figsize=(20, 10))
df = pd.DataFrame(history_CNN_ffill1.history)
df[['loss', 'val_loss']].plot(ax=ax[0])
df[['accuracy', 'val_accuracy']].plot(ax=ax[1])
ax[0].set_title('Model Loss', fontsize=12)
ax[1].set_title('Model Acc', fontsize=12)
fig.suptitle('Model Metrics', fontsize=18)
# Out:
# Text(0.5, 0.98, 'Model Metrics')

# %% [markdown]
# ### Same CNN as before, but training with the noNA dataset

# %%
model_CNN_noNA1 = Sequential() 
model_CNN_noNA1.add(Conv2D(64, kernel_size=(3, 3),activation='relu',input_shape=(96, 96, 1)))
model_CNN_noNA1.add(MaxPooling2D(pool_size=(2, 2)))
model_CNN_noNA1.add(Dropout(0.2))
model_CNN_noNA1.add(Flatten())
model_CNN_noNA1.add(Dense(96))
model_CNN_noNA1.add(BatchNormalization())
model_CNN_noNA1.add(Activation('relu'))
model_CNN_noNA1.add(Dense(30))
 

# model_CNN_noNA1.summary()

model_CNN_noNA1.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])
history_CNN_noNA1 = model_CNN_noNA1.fit(train_data_noNA, train_labels_noNA, batch_size=64, epochs=100, validation_data=(dev_data, dev_labels), shuffle = True, callbacks=[earlyStopping, rlp])
score_CNN_noNA1 = model_CNN_noNA1.evaluate(dev_data, dev_labels)
print('Test score:', score_CNN_noNA1[0]) 
print('Test accuracy:', score_CNN_noNA1[1])
# Out:
# Epoch 1/100
# 26/26 [==============================] - 7s 273ms/step - loss: 2590.6704 - accuracy: 0.0555 - val_loss: 2445.5205 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 2/100
# 26/26 [==============================] - 7s 266ms/step - loss: 2478.7507 - accuracy: 0.0976 - val_loss: 2392.9126 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 3/100
# 26/26 [==============================] - 7s 266ms/step - loss: 2349.8132 - accuracy: 0.1146 - val_loss: 2351.7744 - val_accuracy: 0.0120 - lr: 0.0010
# Epoch 4/100
# 26/26 [==============================] - 7s 263ms/step - loss: 2197.7390 - accuracy: 0.1287 - val_loss: 2223.3557 - val_accuracy: 0.0160 - lr: 0.0010
# Epoch 5/100
# 26/26 [==============================] - 7s 264ms/step - loss: 2028.8811 - accuracy: 0.1366 - val_loss: 2065.5229 - val_accuracy: 0.1820 - lr: 0.0010
# Epoch 6/100
# 26/26 [==============================] - 7s 264ms/step - loss: 1845.6335 - accuracy: 0.1494 - val_loss: 1902.2806 - val_accuracy: 0.3300 - lr: 0.0010
# Epoch 7/100
# 26/26 [==============================] - 7s 265ms/step - loss: 1658.3370 - accuracy: 0.1750 - val_loss: 1698.9642 - val_accuracy: 0.3260 - lr: 0.0010
# Epoch 8/100
# 26/26 [==============================] - 7s 262ms/step - loss: 1468.3689 - accuracy: 0.2024 - val_loss: 1472.1583 - val_accuracy: 0.3360 - lr: 0.0010
# Epoch 9/100
# 26/26 [==============================] - 7s 265ms/step - loss: 1283.2800 - accuracy: 0.2415 - val_loss: 1272.3625 - val_accuracy: 0.4460 - lr: 0.0010
# Epoch 10/100
# 26/26 [==============================] - 7s 264ms/step - loss: 1106.9325 - accuracy: 0.2604 - val_loss: 1076.6691 - val_accuracy: 0.4880 - lr: 0.0010
# Epoch 11/100
# 26/26 [==============================] - 7s 263ms/step - loss: 942.9838 - accuracy: 0.2970 - val_loss: 926.1442 - val_accuracy: 0.4920 - lr: 0.0010
# Epoch
- val_accuracy: 0.8300 - lr: 4.9000e-04
# Epoch 86/100
# 26/26 [==============================] - 7s 263ms/step - loss: 7.1813 - accuracy: 0.7012 - val_loss: 9.5211 - val_accuracy: 0.8260 - lr: 4.9000e-04
# Epoch 87/100
# 26/26 [==============================] - 7s 264ms/step - loss: 7.3443 - accuracy: 0.7012 - val_loss: 7.7224 - val_accuracy: 0.8280 - lr: 4.9000e-04
# Epoch 88/100
# 26/26 [==============================] - 7s 264ms/step - loss: 6.9688 - accuracy: 0.7043 - val_loss: 9.7932 - val_accuracy: 0.8320 - lr: 4.9000e-04
# Epoch 89/100
# 26/26 [==============================] - 7s 263ms/step - loss: 7.7080 - accuracy: 0.7091 - val_loss: 9.6779 - val_accuracy: 0.8280 - lr: 4.9000e-04
# Epoch 90/100
# 26/26 [==============================] - 7s 263ms/step - loss: 7.1777 - accuracy: 0.7055 - val_loss: 10.8188 - val_accuracy: 0.8300 - lr: 4.9000e-04
# Epoch 91/100
# 26/26 [==============================] - 7s 264ms/step - loss: 6.7701 - accuracy: 0.7073 - val_loss: 8.0039 - val_accuracy: 0.8260 - lr: 4.9000e-04
# Epoch 92/100
# 26/26 [==============================] - ETA: 0s - loss: 6.7157 - accuracy: 0.7061
# Epoch 92: ReduceLROnPlateau reducing learning rate to 0.00034300000406801696.
# 26/26 [==============================] - 7s 263ms/step - loss: 6.7157 - accuracy: 0.7061 - val_loss: 8.0472 - val_accuracy: 0.8360 - lr: 4.9000e-04
# Epoch 93/100
# 26/26 [==============================] - 7s 265ms/step - loss: 7.3190 - accuracy: 0.7037 - val_loss: 8.2103 - val_accuracy: 0.8300 - lr: 3.4300e-04
# Epoch 94/100
# 26/26 [==============================] - 7s 263ms/step - loss: 7.1808 - accuracy: 0.7073 - val_loss: 8.3276 - val_accuracy: 0.8280 - lr: 3.4300e-04
# Epoch 95/100
# 26/26 [==============================] - 7s 264ms/step - loss: 6.4738 - accuracy: 0.7098 - val_loss: 7.9503 - val_accuracy: 0.8260 - lr: 3.4300e-04
# Epoch 96/100
# 26/26 [==============================] - 7s 263ms/step - loss: 6.9143 - accuracy: 0.7079 - val_loss: 8.9966 - val_accuracy: 0.8260 - lr: 3.4300e-04
# Epoch 97/100
# 26/26 [==============================] - ETA: 0s - loss: 6.9150 - accuracy: 0.7085
# Epoch 97: ReduceLROnPlateau reducing learning rate to 0.00024009999469853935.
# 26/26 [==============================] - 7s 263ms/step - loss: 6.9150 - accuracy: 0.7085 - val_loss: 8.9751 - val_accuracy: 0.8280 - lr: 3.4300e-04
# Epoch 98/100
# 26/26 [==============================] - 7s 264ms/step - loss: 6.5569 - accuracy: 0.7030 - val_loss: 8.5143 - val_accuracy: 0.8300 - lr: 2.4010e-04
# Epoch 99/100
# 26/26 [==============================] - 7s 265ms/step - loss: 6.8151 - accuracy: 0.7067 - val_loss: 8.4629 - val_accuracy: 0.8260 - lr: 2.4010e-04
# Epoch 100/100
# 26/26 [==============================] - 7s 265ms/step - loss: 6.3993 - accuracy: 0.7061 - val_loss: 8.9298 - val_accuracy: 0.8320 - lr: 2.4010e-04
# 16/16 [==============================] - 2s 135ms/step - loss: 8.9298 - accuracy: 0.8320
# Test score: 8.929766654968262
# Test accuracy: 0.8320000171661377

# %%
sns.set_style('darkgrid')

fig, ax = plt.subplots(2, 1, figsize=(20, 10))
df = pd.DataFrame(history_CNN_noNA1.history)
df[['loss', 'val_loss']].plot(ax=ax[0])
df[['accuracy', 'val_accuracy']].plot(ax=ax[1])
ax[0].set_title('Model Loss', fontsize=12)
ax[1].set_title('Model Acc', fontsize=12)
fig.suptitle('Model Metrics', fontsize=18)
# Out:
# Text(0.5, 0.98, 'Model Metrics')

# %% [markdown]
# ### Transfer learning with Resnet50: CNN with Pre-trained Resnet and one dense layer

# %%
model_resnet_noNA_D1 = Sequential() 
pretrained_model = ResNet50(input_shape=(96,96,3), include_top=False, weights='imagenet')
pretrained_model.trainable = True

model_resnet_noNA_D1.add(Conv2D(3, kernel_size=(1, 1), activation='relu', padding= 'same' ,input_shape=(96, 96, 1)))
model_resnet_noNA_D1.add(LeakyReLU(alpha=0.1))
model_resnet_noNA_D1.add(pretrained_model)
model_resnet_noNA_D1.add(MaxPooling2D(pool_size=(2, 2)))
model_resnet_noNA_D1.add(Dropout(0.1))
model_resnet_noNA_D1.add(Flatten())
model_resnet_noNA_D1.add(Dense(30))
model_resnet_noNA_D1.summary()

model_resnet_noNA_D1.summary()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_23 (Conv2D)          (None, 96, 96, 3)         6
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 96, 96, 3)         0
#
#  resnet50 (Functional)       (None, 3, 3, 2048)        23587712
#
#  max_pooling2d_22 (MaxPoolin  (None, 1, 1, 2048)       0
#  g2D)
#
#  dropout_18 (Dropout)        (None, 1, 1, 2048)        0
#
#  flatten_18 (Flatten)        (None, 2048)              0
#
#  dense_33 (Dense)            (None, 30)                61470
#
# =================================================================
# Total params: 23,649,188
# Trainable params: 23,596,068
# Non-trainable params: 53,120
# _________________________________________________________________
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_23 (Conv2D)          (None, 96, 96, 3)         6
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 96, 96, 3)         0
#
#  resnet50 (Functional)       (None, 3, 3, 2048)        23587712
#
#  max_pooling2d_22 (MaxPoolin  (None, 1, 1, 2048)       0
#  g2D)
#
#  dropout_18 (Dropout)        (None, 1, 1, 2048)        0
#
#  flatten_18 (Flatten)        (None, 2048)              0
#
#  dense_33 (Dense)            (None, 30)                61470
#
# =================================================================
# Total params: 23,649,188
# Trainable params: 23,596,068
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
model_resnet_noNA_D1.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])

history_resnet_noNA_D1 = model_resnet_noNA_D1.fit(train_data_noNA, train_labels_noNA, batch_size=64, epochs=100, validation_data=(dev_data, dev_labels), shuffle = True, callbacks=[earlyStopping, rlp])
score_resnet_noNA_D1 = model_resnet_noNA_D1.evaluate(dev_data, dev_labels)
print('Test score:', score_resnet_noNA_D1[0]) 
print('Test accuracy:', score_resnet_noNA_D1[1])
# Out:
# Epoch 1/100
# 26/26 [==============================] - 13s 380ms/step - loss: 292.3643 - accuracy: 0.4927 - val_loss: 679.4143 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 2/100
# 26/26 [==============================] - 6s 245ms/step - loss: 12.0656 - accuracy: 0.6067 - val_loss: 42.1054 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 3/100
# 26/26 [==============================] - 6s 245ms/step - loss: 9.8761 - accuracy: 0.6256 - val_loss: 229.9854 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 4/100
# 26/26 [==============================] - 6s 245ms/step - loss: 7.5285 - accuracy: 0.6427 - val_loss: 208.4995 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 5/100
# 26/26 [==============================] - 6s 246ms/step - loss: 6.3099 - accuracy: 0.6341 - val_loss: 144.7639 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 6/100
# 26/26 [==============================] - 6s 245ms/step - loss: 6.0939 - accuracy: 0.6738 - val_loss: 114.3785 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 7/100
# 26/26 [==============================] - ETA: 0s - loss: 5.2123 - accuracy: 0.6780
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0007000000332482159.
# 26/26 [==============================] - 6s 245ms/step - loss: 5.2123 - accuracy: 0.6780 - val_loss: 71.6709 - val_accuracy: 0.1660 - lr: 0.0010
# Epoch 8/100
# 26/26 [==============================] - 6s 245ms/step - loss: 4.6668 - accuracy: 0.6957 - val_loss: 59.4189 - val_accuracy: 0.1660 - lr: 7.0000e-04
# Epoch 9/100
# 26/26 [==============================] - 6s 246ms/step - loss: 4.3819 - accuracy: 0.7329 - val_loss: 49.0476 - val_accuracy: 0.1660 - lr: 7.0000e-04
# Epoch 10/100
# 26/26 [==============================] - 6s 246ms/step - loss: 4.2856 - accuracy: 0.7226 - val_loss: 45.1130 - val_accuracy: 0.1660 - lr: 7.0000e-04
# Epoch 11/100
# 26/26 [==============================] - 6s 245ms/step - loss: 4.0219 - accuracy: 0.7409 - val_loss: 47.8437 - val_accuracy: 0.1660 - lr: 7.0000e-04
# Epoch 12/100
# 26/26 [==============================] - 6s 245ms/step - loss: 3.6851 - accuracy: 0.7549 - val_loss: 41.1707 - val_accuracy: 0.1660 - lr: 7.0000e-04
# Epoch 13/100
# 26/26 [==============================] - 6s 245ms/step - loss: 3.6351 - accuracy: 0.7530 - val_loss: 38.1300 - val_accuracy: 0.1660 - lr: 7.0000e-04
# Epoch 14/100
# 26/26 [==============================] - 6s 245ms/step - loss: 3.8170 - accuracy: 0.7579 - val_loss: 35.9117 - val_accuracy: 0.1660 - lr: 7.0000e-04
# Epoch 15/100
# 26/26 [==============================] - 6s 246ms/step - loss: 3.6409 - accuracy: 0.7768 - val_loss: 33.9438 - val_accuracy: 0.1660 - lr: 7.0000e-04
# Epoch 16/100
# 26/26 [==============================] - 6s 245ms/step - loss: 3.3902 - accuracy: 0.7610 - val_loss: 34.8747 - val_accuracy: 0.1660 - lr: 7.0000e-04
# Epoch 17/100
# 26/26 [==============================] - 6s 245ms/step - loss: 3.1451 - accuracy: 0.7829 - val_loss: 36.3794 - val_accuracy: 0.1660 - lr: 7.0000e-04
# Epoch 18/100
# 26/26 [==============================] - 6s 245ms/step - loss: 3.4429 - accuracy: 0.7671 - val_loss: 33.3971 - val_accuracy: 0.1660 - lr: 7.0000e-04
# Epoch 19/100
# 26/26 [==============================] - 6s 245ms/step - loss: 3.2559 - accuracy: 0.7610 - val_loss: 35.0561 - val_accuracy: 0.1660 - lr: 7.0000e-04
# Epoch 20/100
# 26/26 [==============================] - 6s 245ms/step - loss: 3.1726 - accuracy: 0.7823 - val_loss: 32.1328 - val_accuracy: 0.1660 - lr: 7.0000e-04
# Epoch 21/100
# 26/26 [==============================] - 6s 245ms/step - loss: 3.1309 - accuracy: 0.7866 - val_loss: 31.6364 - val_accuracy: 0.1660 - lr: 7.0000e-04
# Epoch 22/100
# 26/26 [==============================] - 6s 246ms/step - loss: 3.0851 - accuracy: 0.8061 - val_loss: 24.4856 - val_accuracy: 0.1700 - lr: 7.0000e-04
# Epoch 23/100
# 26/26 [==============================] - 6s 245ms/step - loss: 2.9109 - accuracy: 0.7939 - val_loss: 25.1452 - val_accuracy: 0.1740 - lr: 7.0000e-04
# Epoch 24/100
# 26/26 [==============================] - 6s 245ms/step - loss: 2.7091 - accuracy: 0.8067 - val_loss: 23.5135 - val_accuracy: 0.2340 - lr: 7.0000e-04
# Epoch 25/100
# 26/26 [==============================] - 6s 245ms/step - loss: 2.7346 - accuracy: 0.7878 - val_loss: 30.6067 - val_accuracy: 0.1800 - lr: 7.0000e-04
# Epoch 26/100
# 26/26 [==============================] - 6s 245ms/step - loss: 2.7661 - accuracy: 0.8018 - val_loss: 24.4868 - val_accuracy: 0.2600 - lr: 7.0000e-04
# Epoch 27/100
# 26/26 [==============================] - 6s 245ms/step - loss: 2.6428 - accuracy: 0.8012 - val_loss: 21.4701 - val_accuracy: 0.2120 - lr: 7.0000e-04
# Epoch 28/100
# 26/26 [==============================] - 6s 245ms/step - loss: 2.5573 - accuracy: 0.8183 - val_loss: 16.4258 - val_accuracy: 0.1980 - lr: 7.0000e-04
# Epoch 29/100
# 26/26 [==============================] - 6s 245ms/step - loss: 2.4903 - accuracy: 0.8171 - val_loss: 15.9679 - val_accuracy: 0.2840 - lr: 7.0000e-04
# Epoch 30/100
# 26/26 [==============================] - 6s 245ms/step - loss: 2.2788 - accuracy: 0.8238 - val_loss: 18.1739 - val_accuracy: 0.3060 - lr: 7.0000e-04
# Epoch 31/100
# 26/26 [==============================] - 6s 245ms/step - loss: 2.3509 - accuracy: 0.8159 - val_loss: 13.5297 - val_accuracy: 0.6100 - lr: 7.0000e-04
# Epoch 32/100
# 26/26 [==============================] - 6s 245ms/step - loss: 2.5129 - accuracy: 0.8183 - val_loss: 12.1667 - val_accuracy: 0.6000 - lr: 7.0000e-04
# Epoch 33/100
# 26/26 [==============================] - 6s 245ms/step - loss: 2.2144 - accuracy: 0.8262 - val_loss: 7.7762 - val_accuracy: 0.6240 - lr: 7.0000e-04
# Epoch 34/100
# 26/26 [==============================] - 6s 245ms/step - loss: 2.2880 - accuracy: 0.8299 - val_loss: 5.9841 - val_accuracy: 0.7760 - lr: 7.0000e-04
# Epoch 35/100
# 26/26 [==============================] - 6s 245ms/step - loss: 2.3071 - accuracy: 0.8195 - val_loss: 13.0242 - val_accuracy: 0.8340 - lr: 7.0000e-04
# Epoch 36/100
# 26/26 [==============================] - 6s 245ms/step - loss: 2.6277 - accuracy: 0.8396 - val_loss: 6.1509 - val_accuracy: 0.8320 - lr: 7.0000e-04
# Epoch 37/100
# 26/26 [==============================] - 6s 245ms/step - loss: 2.8038 - accuracy: 0.8256 - val_loss: 3.4150 - val_accuracy: 0.8040 - lr: 7.0000e-04
# Epoch 38/100
# 26/26 [==============================] - 6s 245ms/step - loss: 2.2937 - accuracy: 0.8201 - val_loss: 3.7888 - val_accuracy: 0.8820 - lr: 7.0000e-04
# Epoch 39/100
# 26/26 [==============================] - 6s 245ms/step - loss: 2.1564 - accuracy: 0.8317 - val_loss: 4.6091 - val_accuracy: 0.8320 - lr: 7.0000e-04
# Epoch 40/100
# 26/26 [==============================] - 6s 247ms/step - loss: 1.9707 - accuracy: 0.8384 - val_loss: 2.2748 - val_accuracy: 0.8720 - lr: 7.0000e-04
# Epoch 41/100
# 26/26 [==============================] - 6s 246ms/step - loss: 2.2704 - accuracy: 0.8317 - val_loss: 2.6676 - val_accuracy: 0.8220 - lr: 7.0000e-04
# Epoch 42/100
# 26/26 [==============================] - 6s 246ms/step - loss: 1.9572 - accuracy: 0.8366 - val_loss: 2.5081 - val_accuracy: 0.8360 - lr: 7.0000e-04
# Epoch 43/100
# 26/26 [==============================] - 6s 247ms/step - loss: 2.0438 - accuracy: 0.8439 - val_loss: 3.7149 - val_accuracy: 0.8900 - lr: 7.0000e-04
# Epoch 44/100
# 26/26 [==============================] - 6s 245ms/step - loss: 2.3342 - accuracy: 0.8354 - val_loss: 1.7903 - val_accuracy: 0.8900 - lr: 7.0000e-04
# Epoch 45/100
# 26/26 [==============================] - 6s 245ms/step - loss: 1.9408 - accuracy: 0.8311 - val_loss: 4.0568 - val_accuracy: 0.8880 - lr: 7.0000e-04
# Epoch 46/100
# 26/26 [==============================] - 6s 245ms/step - loss: 2
100
# 26/26 [==============================] - 6s 245ms/step - loss: 1.0435 - accuracy: 0.8841 - val_loss: 0.7708 - val_accuracy: 0.9200 - lr: 1.6807e-04
# Epoch 93/100
# 26/26 [==============================] - 6s 245ms/step - loss: 1.0476 - accuracy: 0.8915 - val_loss: 0.7885 - val_accuracy: 0.9260 - lr: 1.6807e-04
# Epoch 94/100
# 26/26 [==============================] - 6s 245ms/step - loss: 1.0017 - accuracy: 0.8750 - val_loss: 0.8357 - val_accuracy: 0.9160 - lr: 1.6807e-04
# Epoch 95/100
# 26/26 [==============================] - 6s 245ms/step - loss: 1.0923 - accuracy: 0.8866 - val_loss: 0.8369 - val_accuracy: 0.9080 - lr: 1.6807e-04
# Epoch 96/100
# 26/26 [==============================] - 6s 245ms/step - loss: 1.0097 - accuracy: 0.8762 - val_loss: 0.9036 - val_accuracy: 0.9040 - lr: 1.6807e-04
# Epoch 97/100
# 26/26 [==============================] - ETA: 0s - loss: 0.9818 - accuracy: 0.8915
# Epoch 97: ReduceLROnPlateau reducing learning rate to 0.00011764899536501615.
# 26/26 [==============================] - 6s 245ms/step - loss: 0.9818 - accuracy: 0.8915 - val_loss: 1.1604 - val_accuracy: 0.9080 - lr: 1.6807e-04
# Epoch 98/100
# 26/26 [==============================] - 6s 245ms/step - loss: 0.9847 - accuracy: 0.8921 - val_loss: 0.9953 - val_accuracy: 0.9020 - lr: 1.1765e-04
# Epoch 99/100
# 26/26 [==============================] - 6s 245ms/step - loss: 0.9965 - accuracy: 0.8756 - val_loss: 0.8123 - val_accuracy: 0.9180 - lr: 1.1765e-04
# Epoch 100/100
# 26/26 [==============================] - 6s 245ms/step - loss: 0.9738 - accuracy: 0.8915 - val_loss: 0.8516 - val_accuracy: 0.9020 - lr: 1.1765e-04
# 16/16 [==============================] - 1s 53ms/step - loss: 0.8516 - accuracy: 0.9020
# Test score: 0.8515809774398804
# Test accuracy: 0.9020000696182251

# %%
sns.set_style('darkgrid')

fig, ax = plt.subplots(2, 1, figsize=(20, 10))
df = pd.DataFrame(history_resnet_noNA_D1.history)
df[['loss', 'val_loss']].plot(ax=ax[0])
df[['accuracy', 'val_accuracy']].plot(ax=ax[1])
ax[0].set_title('Model Loss', fontsize=12)
ax[1].set_title('Model Acc', fontsize=12)
fig.suptitle('Model Metrics', fontsize=18)
# Out:
# Text(0.5, 0.98, 'Model Metrics')

# %% [markdown]
# ### Resnet pretrained with two dense layers

# %%
model_resnet_noNA_D2 = Sequential() 
pretrained_model = ResNet50(input_shape=(96,96,3), include_top=False, weights='imagenet')
pretrained_model.trainable = True

model_resnet_noNA_D2.add(Conv2D(3, kernel_size=(1, 1), activation='relu', padding= 'same' ,input_shape=(96, 96, 1)))
model_resnet_noNA_D2.add(LeakyReLU(alpha=0.1))
model_resnet_noNA_D2.add(pretrained_model)
model_resnet_noNA_D2.add(MaxPooling2D(pool_size=(2, 2)))
model_resnet_noNA_D2.add(Dropout(0.1))
model_resnet_noNA_D2.add(Flatten())
model_resnet_noNA_D2.add(Dense(96))
model_resnet_noNA_D2.add(Dense(30))


model_resnet_noNA_D2.summary()
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_24 (Conv2D)          (None, 96, 96, 3)         6
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 96, 96, 3)         0
#
#  resnet50 (Functional)       (None, 3, 3, 2048)        23587712
#
#  max_pooling2d_23 (MaxPoolin  (None, 1, 1, 2048)       0
#  g2D)
#
#  dropout_19 (Dropout)        (None, 1, 1, 2048)        0
#
#  flatten_19 (Flatten)        (None, 2048)              0
#
#  dense_34 (Dense)            (None, 96)                196704
#
#  dense_35 (Dense)            (None, 30)                2910
#
# =================================================================
# Total params: 23,787,332
# Trainable params: 23,734,212
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
model_resnet_noNA_D2.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])

history_resnet_noNA_D2 = model_resnet_noNA_D2.fit(train_data_noNA, train_labels_noNA, batch_size=64, epochs=100, validation_data=(dev_data, dev_labels), shuffle = True, callbacks=[earlyStopping, rlp])
score_resnet_noNA_D2 = model_resnet_noNA_D2.evaluate(dev_data, dev_labels)
print('Test score:', score_resnet_noNA_D2[0]) 
print('Test accuracy:', score_resnet_noNA_D2[1])
# Out:
# Epoch 1/100
# 26/26 [==============================] - 12s 324ms/step - loss: 287.2346 - accuracy: 0.4372 - val_loss: 164718.3438 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 2/100
# 26/26 [==============================] - 6s 246ms/step - loss: 13.6297 - accuracy: 0.6146 - val_loss: 782.5842 - val_accuracy: 0.1660 - lr: 0.0010
# Epoch 3/100
# 26/26 [==============================] - 6s 245ms/step - loss: 10.0121 - accuracy: 0.6360 - val_loss: 397.8352 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 4/100
# 26/26 [==============================] - 6s 245ms/step - loss: 8.2045 - accuracy: 0.6671 - val_loss: 215.4863 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 5/100
# 26/26 [==============================] - 6s 246ms/step - loss: 7.8827 - accuracy: 0.6823 - val_loss: 125.6609 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 6/100
# 26/26 [==============================] -
# %%
sns.set_style('darkgrid')

fig, ax = plt.subplots(2, 1, figsize=(20, 10))
df = pd.DataFrame(history_resnet_noNA_D2.history)
df[['loss', 'val_loss']].plot(ax=ax[0])
df[['accuracy', 'val_accuracy']].plot(ax=ax[1])
ax[0].set_title('Model Loss', fontsize=12)
ax[1].set_title('Model Acc', fontsize=12)
fig.suptitle('Model Metrics', fontsize=18)
# Out:
# Text(0.5, 0.98, 'Model Metrics')

# %% [markdown]
# ### ResnetV2 With lots of Dense Layers

# %%
model_resnet_noNA_C1D4 = Sequential() 
pretrained_model = ResNet50V2(input_shape=(96,96,3), include_top=False, weights='imagenet')
pretrained_model.trainable = True

model_resnet_noNA_C1D4.add(Conv2D(64, kernel_size=(2, 2), activation='relu', padding= 'same' ,input_shape=(96, 96, 1)))
model_resnet_noNA_C1D4.add(LeakyReLU(alpha=0.2))
model_resnet_noNA_C1D4.add(Conv2D(3, kernel_size=(1, 1), activation='relu', padding= 'same' ,input_shape=(96, 96, 64)))
model_resnet_noNA_C1D4.add(LeakyReLU(alpha=0.1))
model_resnet_noNA_C1D4.add(pretrained_model)
model_resnet_noNA_C1D4.add(MaxPooling2D(pool_size=(2, 2)))
model_resnet_noNA_C1D4.add(Dropout(0.1))
model_resnet_noNA_C1D4.add(Flatten())
model_resnet_noNA_C1D4.add(Dense(1024))
model_resnet_noNA_C1D4.add(Dense(512))
model_resnet_noNA_C1D4.add(Dense(96))
model_resnet_noNA_C1D4.add(Dense(30))


model_resnet_noNA_C1D4.summary()
# Out:
# Model: "sequential_29"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_40 (Conv2D)          (None, 96, 96, 64)        320
#
#  leaky_re_lu_19 (LeakyReLU)  (None, 96, 96, 64)        0
#
#  conv2d_41 (Conv2D)          (None, 96, 96, 3)         195
#
#  leaky_re_lu_20 (LeakyReLU)  (None, 96, 96, 3)         0
#
#  resnet50v2 (Functional)     (None, 3, 3, 2048)        23564800
#
#  max_pooling2d_47 (MaxPoolin  (None, 1, 1, 2048)       0
#  g2D)
#
#  dropout_29 (Dropout)        (None, 1, 1, 2048)        0
#
#  flatten_28 (Flatten)        (None, 2048)              0
#
#  dense_51 (Dense)            (None, 1024)              2098176
#
#  dense_52 (Dense)            (None, 512)               524800
#
#  dense_53 (Dense)            (None, 96)                49248
#
#  dense_54 (Dense)            (None, 30)                2910
#
# =================================================================
# Total params: 26,240,449
# Trainable params: 26,195,009
# Non-trainable params: 45,440
# _________________________________________________________________

# %%
model_resnet_noNA_C1D4.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])

history_resnet_noNA_C1D4 = model_resnet_noNA_C1D4.fit(train_data_noNA, train_labels_noNA, batch_size=64, epochs=100, validation_data=(dev_data, dev_labels), shuffle = True, callbacks=[earlyStopping, rlp])
score_resnet_noNA_C1D4 = model_resnet_noNA_C1D4.evaluate(dev_data, dev_labels)
print('Test score:', score_resnet_noNA_C1D4[0]) 
print('Test accuracy:', score_resnet_noNA_C1D4[1])
# Out:
# Epoch 1/100
# 26/26 [==============================] - 24s 546ms/step - loss: 445.9962 - accuracy: 0.2805 - val_loss: 1703.4091 - val_accuracy: 0.0020 - lr: 0.0010
# Epoch 2/100
# 26/26 [==============================] - 8s 291ms/step - loss: 30.1093 - accuracy: 0.5939 - val_loss: 296.5736 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 3/100
# 26/26 [==============================] - 7s 266ms/step - loss: 17.4215 - accuracy: 0.6341 - val_loss: 215.2195 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 4/100
# 26/26 [==============================] - 7s 272ms/step - loss: 13.0147 - accuracy: 0.6640 - val_loss: 72.6378 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 5/100
# 26/26 [==============================] - 7s 264ms/step - loss: 11.0364 - accuracy: 0.6543 - val_loss: 28.4772 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 6/100
# 26/26 [==============================] - 7s 266ms/step - loss: 10.0564 - accuracy: 0.6555 - val_loss: 23.9539 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 7/100
# 26/26 [==============================] - 7s 257ms/step - loss: 10.6765 - accuracy: 0.6701 - val_loss: 13.0484 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 8/100
# 26/26 [==============================] - 7s 262ms/step - loss: 10.4830 - accuracy: 0.6744 - val_loss: 16.6438 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 9/100
# 26/26 [==============================] - 7s 259ms/step - loss: 10.1141 - accuracy: 0.6835 - val_loss: 22.9652 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 10/100
# 26/26 [==============================] - 7s 255ms/step - loss: 10.8316 - accuracy: 0.6665 - val_loss: 18.6497 - val_accuracy: 0.8240 - lr: 0.0010
# Epoch 11/100
# 26/26 [==============================] - 7s 259ms/step - loss: 10.0501 - accuracy: 0.6787 - val_loss: 20.2383 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch
# Epoch 69/100
# 26/26 [==============================] - 7s 253ms/step - loss: 2.0229 - accuracy: 0.8555 - val_loss: 1.5642 - val_accuracy: 0.8780 - lr: 2.4010e-04
# Epoch 70/100
# 26/26 [==============================] - 7s 253ms/step - loss: 2.2880 - accuracy: 0.8348 - val_loss: 1.3264 - val_accuracy: 0.8760 - lr: 2.4010e-04
# Epoch 71/100
# 26/26 [==============================] - ETA: 0s - loss: 2.3258 - accuracy: 0.8652
# Epoch 71: ReduceLROnPlateau reducing learning rate to 0.00016806999628897755.
# 26/26 [==============================] - 7s 254ms/step - loss: 2.3258 - accuracy: 0.8652 - val_loss: 1.8970 - val_accuracy: 0.8360 - lr: 2.4010e-04
# Epoch 72/100
# 26/26 [==============================] - 7s 256ms/step - loss: 1.9969 - accuracy: 0.8573 - val_loss: 1.1674 - val_accuracy: 0.8840 - lr: 1.6807e-04
# Epoch 73/100
# 26/26 [==============================] - 7s 257ms/step - loss: 1.9209 - accuracy: 0.8543 - val_loss: 1.4286 - val_accuracy: 0.8860 - lr: 1.6807e-04
# Epoch 74/100
# 26/26 [==============================] - 7s 254ms/step - loss: 1.9184 - accuracy: 0.8555 - val_loss: 1.2272 - val_accuracy: 0.8700 - lr: 1.6807e-04
# Epoch 75/100
# 26/26 [==============================] - 7s 255ms/step - loss: 1.8197 - accuracy: 0.8549 - val_loss: 1.2613 - val_accuracy: 0.8780 - lr: 1.6807e-04
# Epoch 76/100
# 26/26 [==============================] - 7s 255ms/step - loss: 1.8750 - accuracy: 0.8732 - val_loss: 1.2426 - val_accuracy: 0.8780 - lr: 1.6807e-04
# Epoch 77/100
# 26/26 [==============================] - ETA: 0s - loss: 1.8936 - accuracy: 0.8530
# Epoch 77: ReduceLROnPlateau reducing learning rate to 0.00011764899536501615.
# 26/26 [==============================] - 7s 256ms/step - loss: 1.8936 - accuracy: 0.8530 - val_loss: 1.3703 - val_accuracy: 0.8600 - lr: 1.6807e-04
# Epoch 78/100
# 26/26 [==============================] - 7s 258ms/step - loss: 1.8506 - accuracy: 0.8689 - val_loss: 1.1868 - val_accuracy: 0.8720 - lr: 1.1765e-04
# Epoch 79/100
# 26/26 [==============================] - 7s 254ms/step - loss: 1.7550 - accuracy: 0.8799 - val_loss: 1.2329 - val_accuracy: 0.8620 - lr: 1.1765e-04
# Epoch 80/100
# 26/26 [==============================] - 7s 254ms/step - loss: 1.7949 - accuracy: 0.8579 - val_loss: 1.1408 - val_accuracy: 0.8560 - lr: 1.1765e-04
# Epoch 81/100
# 26/26 [==============================] - 7s 256ms/step - loss: 1.6907 - accuracy: 0.8817 - val_loss: 1.1579 - val_accuracy: 0.8780 - lr: 1.1765e-04
# Epoch 82/100
# 26/26 [==============================] - 7s 254ms/step - loss: 1.7405 - accuracy: 0.8805 - val_loss: 1.2991 - val_accuracy: 0.8640 - lr: 1.1765e-04
# Epoch 83/100
# 26/26 [==============================] - 7s 257ms/step - loss: 1.8453 - accuracy: 0.8720 - val_loss: 1.1458 - val_accuracy: 0.8740 - lr: 1.1765e-04
# Epoch 84/100
# 26/26 [==============================] - 7s 255ms/step - loss: 1.7899 - accuracy: 0.8756 - val_loss: 1.2233 - val_accuracy: 0.8540 - lr: 1.1765e-04
# Epoch 85/100
# 26/26 [==============================] - ETA: 0s - loss: 1.8110 - accuracy: 0.8683
# Epoch 85: ReduceLROnPlateau reducing learning rate to 8.235429777414538e-05.
# 26/26 [==============================] - 7s 255ms/step - loss: 1.8110 - accuracy: 0.8683 - val_loss: 1.2829 - val_accuracy: 0.8800 - lr: 1.1765e-04
# Epoch 86/100
# 26/26 [==============================] - 7s 255ms/step - loss: 1.7650 - accuracy: 0.8780 - val_loss: 1.3119 - val_accuracy: 0.8780 - lr: 8.2354e-05
# Epoch 87/100
# 26/26 [==============================] - 7s 256ms/step - loss: 1.7267 - accuracy: 0.8689 - val_loss: 1.1049 - val_accuracy: 0.8740 - lr: 8.2354e-05
# Epoch 88/100
# 26/26 [==============================] - 7s 254ms/step - loss: 1.6357 - accuracy: 0.8854 - val_loss: 1.1165 - val_accuracy: 0.8780 - lr: 8.2354e-05
# Epoch 89/100
# 26/26 [==============================] - 7s 255ms/step - loss: 1.5876 - accuracy: 0.8970 - val_loss: 1.1180 - val_accuracy: 0.8840 - lr: 8.2354e-05
# Epoch 90/100
# 26/26 [==============================] - 7s 254ms/step - loss: 1.6255 - accuracy: 0.8744 - val_loss: 1.2958 - val_accuracy: 0.8660 - lr: 8.2354e-05
# Epoch 91/100
# 26/26 [==============================] - 7s 254ms/step - loss: 1.6903 - accuracy: 0.8780 - val_loss: 1.1068 - val_accuracy: 0.8780 - lr: 8.2354e-05
# Epoch 92/100
# 26/26 [==============================] - 7s 257ms/step - loss: 1.6121 - accuracy: 0.8713 - val_loss: 1.0930 - val_accuracy: 0.8720 - lr: 8.2354e-05
# Epoch 93/100
# 26/26 [==============================] - 7s 254ms/step - loss: 1.7135 - accuracy: 0.8793 - val_loss: 1.3679 - val_accuracy: 0.8620 - lr: 8.2354e-05
# Epoch 94/100
# 26/26 [==============================] - 7s 255ms/step - loss: 1.7864 - accuracy: 0.8689 - val_loss: 1.2136 - val_accuracy: 0.8800 - lr: 8.2354e-05
# Epoch 95/100
# 26/26 [==============================] - 7s 253ms/step - loss: 1.6350 - accuracy: 0.8872 - val_loss: 1.3338 - val_accuracy: 0.8800 - lr: 8.2354e-05
# Epoch 96/100
# 26/26 [==============================] - 7s 255ms/step - loss: 1.5732 - accuracy: 0.8811 - val_loss: 1.1542 - val_accuracy: 0.8660 - lr: 8.2354e-05
# Epoch 97/100
# 26/26 [==============================] - ETA: 0s - loss: 1.6400 - accuracy: 0.8817
# Epoch 97: ReduceLROnPlateau reducing learning rate to 5.76480058953166e-05.
# 26/26 [==============================] - 7s 255ms/step - loss: 1.6400 - accuracy: 0.8817 - val_loss: 1.2672 - val_accuracy: 0.8820 - lr: 8.2354e-05
# Epoch 98/100
# 26/26 [==============================] - 7s 256ms/step - loss: 1.7171 - accuracy: 0.8835 - val_loss: 1.1166 - val_accuracy: 0.8820 - lr: 5.7648e-05
# Epoch 99/100
# 26/26 [==============================] - 7s 253ms/step - loss: 1.5246 - accuracy: 0.8720 - val_loss: 1.1617 - val_accuracy: 0.8760 - lr: 5.7648e-05
# Epoch 100/100
# 26/26 [==============================] - 7s 256ms/step - loss: 1.5781 - accuracy: 0.8835 - val_loss: 1.0842 - val_accuracy: 0.8820 - lr: 5.7648e-05
# 16/16 [==============================] - 3s 139ms/step - loss: 1.0842 - accuracy: 0.8820
# Test score: 1.0841823816299438
# Test accuracy: 0.8820000290870667

# %%
sns.set_style('darkgrid')

fig, ax = plt.subplots(2, 1, figsize=(20, 10))
df = pd.DataFrame(history_resnet_noNA_C1D4.history)
df[['loss', 'val_loss']].plot(ax=ax[0])
df[['accuracy', 'val_accuracy']].plot(ax=ax[1])
ax[0].set_title('Model Loss', fontsize=12)
ax[1].set_title('Model Acc', fontsize=12)
fig.suptitle('Model Metrics', fontsize=18)
# Out:
# Text(0.5, 0.98, 'Model Metrics')

# %%
y_pred = model_resnet_noNA_C1D4.predict(dev_data)
show_images(dev_data, y_pred)
show_images(dev_data, dev_labels)

# %% [markdown]
# ### Efficient Net (1 Dense Layer)

# %%
model_effnetB7_noNA_D1 = Sequential() 
pretrained_model = EfficientNetB7(input_shape= (96, 96, 3), include_top= False, weights='imagenet')
pretrained_model.trainable = True

model_effnetB7_noNA_D1.add(Conv2D(3, kernel_size=(1, 1), activation='relu', padding= 'same' ,input_shape=(96, 96, 1)))
model_effnetB7_noNA_D1.add(LeakyReLU(alpha=0.1))
model_effnetB7_noNA_D1.add(pretrained_model)
model_effnetB7_noNA_D1.add(MaxPooling2D(pool_size=(2, 2)))
model_effnetB7_noNA_D1.add(Dropout(0.1))
model_effnetB7_noNA_D1.add(Flatten())
model_effnetB7_noNA_D1.add(Dense(30))


model_effnetB7_noNA_D1.summary()
# Out:
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_27 (Conv2D)          (None, 96, 96, 3)         6
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 96, 96, 3)         0
#
#  efficientnetb7 (Functional)  (None, 3, 3, 2560)       64097687
#
#  max_pooling2d_25 (MaxPoolin  (None, 1, 1, 2560)       0
#  g2D)
#
#  dropout_22 (Dropout)        (None, 1, 1, 2560)        0
#
#  flatten_21 (Flatten)        (None, 2560)              0
#
#  dense_38 (Dense)            (None, 30)                76830
#
# =================================================================
# Total params: 64,174,523
# Trainable params: 63,863,796
# Non-trainable params: 310,727
# _________________________________________________________________

# %%
model_effnetB7_noNA_D1.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])

history_effnetB7_noNA_D1 = model_effnetB7_noNA_D1.fit(train_data_noNA, train_labels_noNA, batch_size=64, epochs=100, validation_data=(dev_data, dev_labels), shuffle = True, callbacks=[earlyStopping, rlp])
score_effnetB7_noNA_D1 = model_effnetB7_noNA_D1.evaluate(dev_data, dev_labels)
print('Test score:', score_effnetB7_noNA_D1[0]) 
print('Test accuracy:', score_effnetB7_noNA_D1[1])
# Out:
# Epoch 1/100
# 26/26 [==============================] - 89s 2s/step - loss: 341.1995 - accuracy: 0.4970 - val_loss: 1439.1626 - val_accuracy: 0.1660 - lr: 0.0010
# Epoch 2/100
# 26/26 [==============================] - 33s 1s/step - loss: 16.2628 - accuracy: 0.6537 - val_loss: 449.7756 - val_accuracy: 0.1660 - lr: 0.0010
# Epoch 3/100
# 26/26 [==============================] - 95s 4s/step - loss: 13.6627 - accuracy: 0.6518 - val_loss: 103.3230 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 4/100
# 26/26 [==============================] - 133s 5s/step - loss: 13.3760 - accuracy: 0.6616 - val_loss: 123.9812 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 5/100
# 26/26 [==============================] - 29s 1s/step - loss: 14.5158 - accuracy: 0.6555 - val_loss: 78.3758 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 6/100
# 26/26 [==============================] - 35s 1s/step - loss: 12.9915 - accuracy: 0.6561 - val_loss: 71.0735 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 7/100
# 26/26 [==============================] - 43s 2s/step - loss: 13.0202 - accuracy: 0.6561 - val_loss: 30.5277 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 8/100
# 26/26 [==============================] - 339s 13s/step - loss: 12.4250 - accuracy: 0.6439 - val_loss: 34.1041 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 9/100
# 26/26 [==============================] - 316s 13s/step - loss: 12.3246 - accuracy: 0.6506 - val_loss: 22.6276 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 10/100
# 26/26 [==============================] - 30s 1s/step - loss: 12.6163 - accuracy: 0.6579 - val_loss: 17.0777 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 11/100
# 26/26 [==============================] - 29s 1s/step - loss: 12.4289 - accuracy: 0.6518 - val_loss: 17.6615 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 12/100
# 26/26 [==============================] - 30s 1s/step - loss: 12.4741 - accuracy: 0.6530 - val_loss: 9.0518 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 13/100
# 26/26 [==============================] - 30s 1s/step - loss: 12.7919 - accuracy: 0.6585 - val_loss: 13.5260 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 14/100
# 26/26 [==============================] - 30s 1s/step - loss: 12.6557 - accuracy: 0.6482 - val_loss: 13.1767 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 15/100
# 26/26 [==============================] - 30s 1s/step - loss: 12.4449 - accuracy: 0.6518 - val_loss: 9.8597 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 16/100
# 26/26 [==============================] - 30s 1s/step - loss: 12.3251 - accuracy: 0.6555 - val_loss: 8.7823 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 17/100
# 26/26 [==============================] - 29s 1s/step - loss: 12.2529 - accuracy: 0.6579 - val_loss: 9.5760 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 18/100
# 26/26 [==============================] - 29s 1s/step - loss: 12.3162 - accuracy: 0.6567 - val_loss: 11.9274 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 19/100
# 26/26 [==============================] - 466s 19s/step - loss: 12.3195 - accuracy: 0.6518 - val_loss: 8.1953 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 20/100
# 26/26 [==============================] - 1010s 40s/step - loss: 12.4643 - accuracy: 0.6555 - val_loss: 8.9103 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 21/100
# 26/26 [==============================] - 91s 4s/step - loss: 12.5201 - accuracy: 0.6591 - val_loss: 9.0536 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 22/100
# 26/26 [==============================] - 30s 1s/step - loss: 12.3974 - accuracy: 0.6628 - val_loss: 8.7769 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 23/100
# 26/26 [==============================] - 29s 1s/step - loss: 12.4186 - accuracy: 0.6634 - val_loss: 9.0836 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 24/100
# 26/26 [==============================] - ETA: 0s - loss: 12.2492 - accuracy: 0.6549
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0007000000332482159.
# 26/26 [==============================] -
100
# 26/26 [==============================] - 30s 1s/step - loss: 11.5240 - accuracy: 0.6634 - val_loss: 8.4841 - val_accuracy: 0.8300 - lr: 6.7822e-06
# Epoch 95/100
# 26/26 [==============================] - ETA: 0s - loss: 11.5801 - accuracy: 0.6683
# Epoch 95: ReduceLROnPlateau reducing learning rate to 4.747560842588427e-06.
# 26/26 [==============================] - 30s 1s/step - loss: 11.5801 - accuracy: 0.6683 - val_loss: 8.4660 - val_accuracy: 0.8300 - lr: 6.7822e-06
# Epoch 96/100
# 26/26 [==============================] - 30s 1s/step - loss: 11.5694 - accuracy: 0.6646 - val_loss: 8.5643 - val_accuracy: 0.8300 - lr: 4.7476e-06
# Epoch 97/100
# 26/26 [==============================] - 31s 1s/step - loss: 11.5531 - accuracy: 0.6652 - val_loss: 8.5062 - val_accuracy: 0.8300 - lr: 4.7476e-06
# Epoch 98/100
# 26/26 [==============================] - 30s 1s/step - loss: 11.5395 - accuracy: 0.6634 - val_loss: 8.5168 - val_accuracy: 0.8300 - lr: 4.7476e-06
# Epoch 99/100
# 26/26 [==============================] - 30s 1s/step - loss: 11.5447 - accuracy: 0.6652 - val_loss: 8.3757 - val_accuracy: 0.8300 - lr: 4.7476e-06
# Epoch 100/100
# 26/26 [==============================] - ETA: 0s - loss: 11.6057 - accuracy: 0.6659
# Epoch 100: ReduceLROnPlateau reducing learning rate to 3.3232926853088427e-06.
# 26/26 [==============================] - 30s 1s/step - loss: 11.6057 - accuracy: 0.6659 - val_loss: 8.5532 - val_accuracy: 0.8300 - lr: 4.7476e-06
# 16/16 [==============================] - 8s 391ms/step - loss: 8.5532 - accuracy: 0.8300
# Test score: 8.553211212158203
# Test accuracy: 0.8300000429153442

# %%
sns.set_style('darkgrid')

fig, ax = plt.subplots(2, 1, figsize=(20, 10))
df = pd.DataFrame(history_effnetB7_noNA_D1.history)
df[['loss', 'val_loss']].plot(ax=ax[0])
df[['accuracy', 'val_accuracy']].plot(ax=ax[1])
ax[0].set_title('Model Loss', fontsize=12)
ax[1].set_title('Model Acc', fontsize=12)
fig.suptitle('Model Metrics', fontsize=18)
# Out:
# Text(0.5, 0.98, 'Model Metrics')

# %%
# for image, label in ds_train.take(1):
#     for i in range(9):
#         ax = plt.subplot(3, 3, i + 1)
#         aug_img = img_augmentation(tf.expand_dims(image, axis=0))
#         plt.imshow(aug_img[0].numpy().astype("uint8"))
#         plt.title("{}".format(format_label(label)))
#         plt.axis("off")

#Great code block for showing augmentation examples

# %% [markdown]
# ### EfficientNet_v2B3 try number 2 (two conv, two dense, using Efficientnetv2_B3)

# %%
model_effnetV2B3_noNA_C2D2 = Sequential() 
pretrained_model = EfficientNetV2B3(input_shape= (96, 96, 3), include_top= False, weights='imagenet')
pretrained_model.trainable = True

model_effnetV2B3_noNA_C2D2.add(Conv2D(24, kernel_size=(2, 2), activation='relu', padding= 'same' ,input_shape=(96, 96, 1)))
model_effnetV2B3_noNA_C2D2.add(LeakyReLU(alpha=0.2))
model_effnetV2B3_noNA_C2D2.add(Conv2D(3, kernel_size=(1, 1), activation='relu', padding= 'same' ,input_shape=(96, 96, 24)))
model_effnetV2B3_noNA_C2D2.add(LeakyReLU(alpha=0.1))
model_effnetV2B3_noNA_C2D2.add(pretrained_model)
model_effnetV2B3_noNA_C2D2.add(MaxPooling2D(pool_size=(2, 2)))
model_effnetV2B3_noNA_C2D2.add(Dropout(0.1))
model_effnetV2B3_noNA_C2D2.add(Flatten())
model_effnetV2B3_noNA_C2D2.add(Dense(90))
model_effnetV2B3_noNA_C2D2.add(Dense(30))



model_effnetV2B3_noNA_C2D2.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b3_notop.h5
# 52609024/52606240 [==============================] - 5s 0us/step
# 52617216/52606240 [==============================] - 5s 0us/step
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_30 (Conv2D)          (None, 96, 96, 24)        120
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 96, 96, 24)        0
#
#  conv2d_31 (Conv2D)          (None, 96, 96, 3)         75
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 96, 96, 3)         0
#
#  efficientnetv2-b3 (Function  (None, 3, 3, 1536)       12930622
#  al)
#
#  max_pooling2d_27 (MaxPoolin  (None, 1, 1, 1536)       0
#  g2D)
#
#  dropout_24 (Dropout)        (None, 1, 1, 1536)        0
#
#  flatten_23 (Flatten)        (None, 1536)              0
#
#  dense_41 (Dense)            (None, 90)                138330
#
#  dense_42 (Dense)            (None, 30)                2730
#
# =================================================================
# Total params: 13,071,877
# Trainable params: 12,962,661
# Non-trainable params: 109,216
# _________________________________________________________________

# %%
model_effnetV2B3_noNA_C2D2.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])

history_effnetV2B3_noNA_C2D2 = model_effnetV2B3_noNA_C2D2.fit(train_data_noNA, train_labels_noNA, batch_size=64, epochs=100, validation_data=(dev_data, dev_labels), shuffle = True, callbacks=[earlyStopping, rlp])
score_effnetV2B3_noNA_C2D2 = model_effnetV2B3_noNA_C2D2.evaluate(dev_data, dev_labels)
print('Test score:', score_effnetV2B3_noNA_C2D2[0]) 
print('Test accuracy:', score_effnetV2B3_noNA_C2D2[1])
# Out:
# Epoch 1/100
# 26/26 [==============================] - 45s 952ms/step - loss: 384.7906 - accuracy: 0.2579 - val_loss: 1420.2065 - val_accuracy: 0.1660 - lr: 0.0010
# Epoch 2/100
# 26/26 [==============================] - 10s 379ms/step - loss: 13.9964 - accuracy: 0.6354 - val_loss: 1160.0442 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 3/100
# 26/26 [==============================] - 8s 315ms/step - loss: 12.7362 - accuracy: 0.6646 - val_loss: 456.6062 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 4/100
# 26/26 [==============================] - 9s 333ms/step - loss: 12.9386 - accuracy: 0.6665 - val_loss: 15.8116 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 5/100
# 26/26 [==============================] - 8s 292ms/step - loss: 12.2452 - accuracy: 0.6652 - val_loss: 685.2131 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 6/100
# 26/26 [==============================] - 8s 300ms/step - loss: 12.2859 - accuracy: 0.6659 - val_loss: 2583.2793 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 7/100
# 26/26 [==============================] - 8s 300ms/step - loss: 12.9433 - accuracy: 0.6622 - val_loss: 2090.6038 - val_accuracy: 0.0020 - lr: 0.0010
# Epoch 8/100
# 26/26 [==============================] - 8s 313ms/step - loss: 12.0738 - accuracy: 0.6659 - val_loss: 1083.6216 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 9/100
# 26/26 [==============================] - ETA: 0s - loss: 12.4805 - accuracy: 0.6628
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0007000000332482159.
# 26/26 [==============================] - 8s 295ms/step - loss: 12.4805 - accuracy: 0.6628 - val_loss: 1254.1788 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 10/100
# 26/26 [==============================] - 8s 291ms/step - loss: 11.9085 - accuracy: 0.6671 - val_loss: 2571.6458 - val_accuracy: 0.0000e+00 - lr: 7.0000e-04
# Epoch 11/100
# 26/26 [==============================] - 8s 325ms/step - loss: 11.6876 - accuracy: 0.6628 - val_loss: 1247.5876 - val_accuracy: 0.8300 - lr: 7.0000e-04
# Epoch 12/100
# 26/26 [==============================] - 8s 296ms/step - loss: 11.6066 - accuracy: 0.6689 - val_loss: 1021.4514 - val_accuracy: 0.8300 - lr: 7.0000e-04
# Epoch 13/100
# 26/26 [==============================] - 7s 286ms/step - loss: 11.4893 - accuracy: 0.6652 - val_loss: 924.3760 - val_accuracy: 0.8300 - lr: 7.0000e-04
# Epoch 14/100
# 26/26 [==============================] - ETA: 0s - loss: 11.8084 - accuracy: 0.6659
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0004900000232737511.
# 26/26 [==============================] - 8s 307ms/step - loss: 11.8084 - accuracy: 0.6659 - val_loss: 2302.8008 - val_accuracy: 0.8300 - lr: 7.0000e-04
# Epoch 15/100
# 26/26 [==============================] - 7s 284ms/step - loss: 10.5847 - accuracy: 0.6683 - val_loss: 1473.7875 - val_accuracy: 0.4880 - lr: 4.9000e-04
# Epoch 16/100
# 26/26 [==============================] - 8s 292ms/step - loss: 9.8356 - accuracy: 0.6659 - val_loss: 1284.3110 - val_accuracy: 0.1660 - lr: 4.9000e-04
# Epoch 17/100
# 26/26 [==============================] - 36s 1s/step - loss: 9.1244 - accuracy: 0.6659 - val_loss: 553.2028 - val_accuracy: 0.1660 - lr: 4.9000e-04
# Epoch 18/100
# 26/26 [==============================] - 7s 284ms/step - loss: 7.8751 - accuracy: 0.6659 - val_loss: 306.4088 - val_accuracy: 0.1660 - lr: 4.9000e-04
# Epoch
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.00016806999628897755.
# 26/26 [==============================] - 7s 283ms/step - loss: 2.5883 - accuracy: 0.7951 - val_loss: 10.0028 - val_accuracy: 0.6060 - lr: 2.4010e-04
# Epoch 38/100
# 26/26 [==============================] - 7s 287ms/step - loss: 2.5369 - accuracy: 0.8104 - val_loss: 1.6453 - val_accuracy: 0.8700 - lr: 1.6807e-04
# Epoch 39/100
# 26/26 [==============================] - 8s 317ms/step - loss: 2.3389 - accuracy: 0.8110 - val_loss: 2.7618 - val_accuracy: 0.8160 - lr: 1.6807e-04
# Epoch 40/100
# 26/26 [==============================] - 8s 328ms/step - loss: 2.3584 - accuracy: 0.8049 - val_loss: 7.4656 - val_accuracy: 0.8300 - lr: 1.6807e-04
# Epoch 41/100
# 26/26 [==============================] - 9s 338ms/step - loss: 2.3826 - accuracy: 0.8152 - val_loss: 7.2672 - val_accuracy: 0.8720 - lr: 1.6807e-04
# Epoch 42/100
# 26/26 [==============================] - 23s 903ms/step - loss: 2.3238 - accuracy: 0.8073 - val_loss: 3.7544 - val_accuracy: 0.8520 - lr: 1.6807e-04
# Epoch 43/100
# 26/26 [==============================] - ETA: 0s - loss: 2.2944 - accuracy: 0.8146
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.00011764899536501615.
# 26/26 [==============================] - 9s 344ms/step - loss: 2.2944 - accuracy: 0.8146 - val_loss: 2.7936 - val_accuracy: 0.8400 - lr: 1.6807e-04
# Epoch 44/100
# 26/26 [==============================] - 8s 309ms/step - loss: 2.3675 - accuracy: 0.8091 - val_loss: 3.7032 - val_accuracy: 0.8860 - lr: 1.1765e-04
# Epoch 45/100
# 26/26 [==============================] - 10s 369ms/step - loss: 2.2114 - accuracy: 0.8171 - val_loss: 1.6546 - val_accuracy: 0.8700 - lr: 1.1765e-04
# Epoch 46/100
# 26/26 [==============================] - 10s 405ms/step - loss: 2.1223 - accuracy: 0.8159 - val_loss: 5.1422 - val_accuracy: 0.8180 - lr: 1.1765e-04
# Epoch 47/100
# 26/26 [==============================] - 25s 980ms/step - loss: 2.1573 - accuracy: 0.8171 - val_loss: 2.0144 - val_accuracy: 0.8820 - lr: 1.1765e-04
# Epoch 48/100
# 26/26 [==============================] - 14s 564ms/step - loss: 2.0108 - accuracy: 0.8262 - val_loss: 1.4619 - val_accuracy: 0.8800 - lr: 1.1765e-04
# Epoch 49/100
# 26/26 [==============================] - 23s 887ms/step - loss: 2.0388 - accuracy: 0.8165 - val_loss: 2.9729 - val_accuracy: 0.8560 - lr: 1.1765e-04
# Epoch 50/100
# 26/26 [==============================] - 38s 2s/step - loss: 2.0829 - accuracy: 0.8366 - val_loss: 2.9777 - val_accuracy: 0.8380 - lr: 1.1765e-04
# Epoch 51/100
# 26/26 [==============================] - 14s 529ms/step - loss: 1.9957 - accuracy: 0.8183 - val_loss: 9.5513 - val_accuracy: 0.8520 - lr: 1.1765e-04
# Epoch 52/100
# 26/26 [==============================] - 13s 482ms/step - loss: 1.9368 - accuracy: 0.8165 - val_loss: 1.6733 - val_accuracy: 0.8640 - lr: 1.1765e-04
# Epoch 53/100
# 26/26 [==============================] - ETA: 0s - loss: 1.9008 - accuracy: 0.8317
# Epoch 53: ReduceLROnPlateau reducing learning rate to 8.235429777414538e-05.
# 26/26 [==============================] - 89s 4s/step - loss: 1.9008 - accuracy: 0.8317 - val_loss: 1.5319 - val_accuracy: 0.8720 - lr: 1.1765e-04
# Epoch 54/100
# 26/26 [==============================] - 8s 313ms/step - loss: 1.9013 - accuracy: 0.8274 - val_loss: 1.7563 - val_accuracy: 0.8760 - lr: 8.2354e-05
# Epoch 55/100
# 26/26 [==============================] - 7s 287ms/step - loss: 1.9457 - accuracy: 0.8372 - val_loss: 1.1919 - val_accuracy: 0.8820 - lr: 8.2354e-05
# Epoch 56/100
# 26/26 [==============================] - 7s 284ms/step - loss: 1.8861 - accuracy: 0.8329 - val_loss: 1.2500 - val_accuracy: 0.8660 - lr: 8.2354e-05
# Epoch 57/100
# 26/26 [==============================] - 7s 287ms/step - loss: 1.8624 - accuracy: 0.8348 - val_loss: 2.4516 - val_accuracy: 0.8700 - lr: 8.2354e-05
# Epoch 58/100
# 26/26 [==============================] - 7s 286ms/step - loss: 1.8786 - accuracy: 0.8335 - val_loss: 2.9524 - val_accuracy: 0.8480 - lr: 8.2354e-05
# Epoch 59/100
# 26/26 [==============================] - 18s 724ms/step - loss: 1.8714 - accuracy: 0.8372 - val_loss: 1.2770 - val_accuracy: 0.8560 - lr: 8.2354e-05
# Epoch 60/100
# 26/26 [==============================] - ETA: 0s - loss: 1.8756 - accuracy: 0.8415
# Epoch 60: ReduceLROnPlateau reducing learning rate to 5.76480058953166e-05.
# 26/26 [==============================] - 8s 294ms/step - loss: 1.8756 - accuracy: 0.8415 - val_loss: 2.3125 - val_accuracy: 0.8560 - lr: 8.2354e-05
# Epoch 61/100
# 26/26 [==============================] - 9s 330ms/step - loss: 1.7821 - accuracy: 0.8372 - val_loss: 1.7971 - val_accuracy: 0.8900 - lr: 5.7648e-05
# Epoch 62/100
# 26/26 [==============================] - 9s 347ms/step - loss: 1.7743 - accuracy: 0.8439 - val_loss: 1.2897 - val_accuracy: 0.8600 - lr: 5.7648e-05
# Epoch 63/100
# 26/26 [==============================] - 9s 354ms/step - loss: 1.8031 - accuracy: 0.8634 - val_loss: 2.4379 - val_accuracy: 0.8540 - lr: 5.7648e-05
# Epoch 64/100
# 26/26 [==============================] - 10s 379ms/step - loss: 1.7364 - accuracy: 0.8378 - val_loss: 1.4759 - val_accuracy: 0.8720 - lr: 5.7648e-05
# Epoch 65/100
# 26/26 [==============================] - ETA: 0s - loss: 1.7208 - accuracy: 0.8500
# Epoch 65: ReduceLROnPlateau reducing learning rate to 4.0353603617404586e-05.
# 26/26 [==============================] - 18s 717ms/step - loss: 1.7208 - accuracy: 0.8500 - val_loss: 1.2307 - val_accuracy: 0.8740 - lr: 5.7648e-05
# Epoch 66/100
# 26/26 [==============================] - 23s 879ms/step - loss: 1.7388 - accuracy: 0.8372 - val_loss: 1.1631 - val_accuracy: 0.8780 - lr: 4.0354e-05
# Epoch 67/100
# 26/26 [==============================] - 23s 877ms/step - loss: 1.7299 - accuracy: 0.8433 - val_loss: 1.2960 - val_accuracy: 0.8640 - lr: 4.0354e-05
# Epoch 68/100
# 26/26 [==============================] - 23s 879ms/step - loss: 1.6367 - accuracy: 0.8378 - val_loss: 1.2892 - val_accuracy: 0.8880 - lr: 4.0354e-05
# Epoch 69/100
# 26/26 [==============================] - 23s 882ms/step - loss: 1.6435 - accuracy: 0.8378 - val_loss: 1.3114 - val_accuracy: 0.8760 - lr: 4.0354e-05
# Epoch 70/100
# 26/26 [==============================] - 23s 884ms/step - loss: 1.6365 - accuracy: 0.8482 - val_loss: 1.1326 - val_accuracy: 0.8680 - lr: 4.0354e-05
# Epoch 71/100
# 26/26 [==============================] - 23s 886ms/step - loss: 1.6338 - accuracy: 0.8366 - val_loss: 2.0887 - val_accuracy: 0.8560 - lr: 4.0354e-05
# Epoch 72/100
# 26/26 [==============================] - 23s 884ms/step - loss: 1.6491 - accuracy: 0.8585 - val_loss: 1.1632 - val_accuracy: 0.8820 - lr: 4.0354e-05
# Epoch 73/100
# 26/26 [==============================] - 23s 886ms/step - loss: 1.6311 - accuracy: 0.8470 - val_loss: 1.3332 - val_accuracy: 0.8780 - lr: 4.0354e-05
# Epoch 74/100
# 26/26 [==============================] - 23s 883ms/step - loss: 1.6446 - accuracy: 0.8439 - val_loss: 1.1996 - val_accuracy: 0.8760 - lr: 4.0354e-05
# Epoch 75/100
# 26/26 [==============================] - ETA: 0s - loss: 1.6705 - accuracy: 0.8427
# Epoch 75: ReduceLROnPlateau reducing learning rate to 2.8247522277524694e-05.
# 26/26 [==============================] - 23s 891ms/step - loss: 1.6705 - accuracy: 0.8427 - val_loss: 1.2142 - val_accuracy: 0.8620 - lr: 4.0354e-05
# Epoch 76/100
# 26/26 [==============================] - 23s 890ms/step - loss: 1.5811 - accuracy: 0.8573 - val_loss: 1.3498 - val_accuracy: 0.8780 - lr: 2.8248e-05
# Epoch 77/100
# 26/26 [==============================] - 23s 890ms/step - loss: 1.5659 - accuracy: 0.8482 - val_loss: 1.2085 - val_accuracy: 0.8600 - lr: 2.8248e-05
# Epoch 78/100
# 26/26 [==============================] - 11s 410ms/step - loss: 1.5981 - accuracy: 0.8421 - val_loss: 1.1227 - val_accuracy: 0.8780 - lr: 2.8248e-05
# Epoch 79/100
# 26/26 [==============================] - 9s 332ms/step - loss: 1.6497 - accuracy: 0.8549 - val_loss: 1.6376 - val_accuracy: 0.8720 - lr: 2.8248e-05
# Epoch 80/100
# 26/26 [==============================] - 9s 351ms/step - loss: 1.6142 - accuracy: 0.8476 - val_loss: 1.1204 - val_accuracy: 0.8780 - lr: 2.8248e-05
# Epoch 81/100
# 26/26 [==============================] - 9s 352ms/step - loss: 1.6097 - accuracy: 0.8524 - val_loss: 1.1668 - val_accuracy: 0.8820 - lr: 2.8248e-05
# Epoch 82/100
# 26/26 [==============================] - 9s 349ms/step - loss: 1.5425 - accuracy: 0.8494 - val_loss: 1.2913 - val_accuracy: 0.8660 - lr: 2.8248e-05
# Epoch 83/100
# 26/26 [==============================] - 9s 349ms/step - loss: 1.6168 - accuracy: 0.8628 - val_loss: 1.3417 - val_accuracy: 0.8740 - lr: 2.8248e-05
# Epoch 84/100
# 26/26 [==============================] - 9s 356ms/step - loss: 1.6266 - accuracy: 0.8482 - val_loss: 1.2970 - val_accuracy: 0.8640 - lr: 2.8248e-05
# Epoch 85/100
# 26/26 [==============================] - ETA: 0s - loss: 1.5582 - accuracy: 0.8476
# Epoch 85: ReduceLROnPlateau reducing learning rate to 1.977326610358432e-05.
# 26/26 [==============================] - 9s 364ms/step - loss: 1.5582 - accuracy: 0.8476 - val_loss: 1.2419 - val_accuracy: 0.8740 - lr: 2.8248e-05
# Epoch 86/100
# 26/26 [==============================] - 16s 642ms/step - loss: 1.5496 - accuracy: 0.8451 - val_loss: 1.4184 - val_accuracy: 0.8760 - lr: 1.9773e-05
# Epoch 87/100
# 26/26 [==============================] - 23s 891ms/step - loss: 1.5760 - accuracy: 0.8463 - val_loss: 1.1954 - val_accuracy: 0.8720 - lr: 1.9773e-05
# Epoch 88/100
# 26/26 [==============================] - 23s 894ms/step - loss: 1.5211 - accuracy: 0.8585 - val_loss: 1.0651 - val_accuracy: 0.8860 - lr: 1.9773e-05
# Epoch 89/100
# 26/26 [==============================] - 18s 678ms/step - loss: 1.5217 - accuracy: 0.8555 - val_loss: 1.1185 - val_accuracy: 0.8900 - lr: 1.9773e-05
# Epoch 90/100
# 26/26 [==============================] - 7s 284ms/step - loss: 1.5722 - accuracy: 0.8591 - val_loss: 1.2491 - val_accuracy: 0.8640 - lr: 1.9773e-05
# Epoch 91/100
# 26/26 [==============================] - 7s 288ms/step - loss: 1.5004 - accuracy: 0.8591 - val_loss: 1.0746 - val_accuracy: 0.8920 - lr: 1.9773e-05
# Epoch 92/100
# 26/26 [==============================] - 7s 289ms/step - loss: 1.5118 - accuracy: 0.8451 - val_loss: 2.2104 - val_accuracy: 0.8500 - lr: 1.9773e-05
# Epoch 93/100
# 26/26 [==============================] - ETA: 0s - loss: 1.5459 - accuracy: 0.8549
# Epoch 93: ReduceLROnPlateau reducing learning rate to 1.3841286272509023e-05.
# 26/26 [==============================] - 7s 284ms/step - loss: 1.5459 - accuracy: 0.8549 - val_loss: 1.1718 - val_accuracy: 0.8840 - lr: 1.9773e-05
# Epoch 94/100
# 26/26 [==============================] - 7s 284ms/step - loss: 1.5271 - accuracy: 0.8524 - val_loss: 1.0878 - val_accuracy: 0.8760 - lr: 1.3841e-05
# Epoch 95/100
# 26/26 [==============================] - 7s 286ms/step - loss: 1.4640 - accuracy: 0.8488 - val_loss: 1.0606 - val_accuracy: 0.8800 - lr: 1.3841e-05
# Epoch 96/100
# 26/26 [==============================] - 7s 286ms/step - loss: 1.5130 - accuracy: 0.8512 - val_loss: 1.2202 - val_accuracy: 0.8840 - lr: 1.3841e-05
# Epoch 97/100
# 26/26 [==============================] - 7s 287ms/step - loss: 1.5150 - accuracy: 0.8439 - val_loss: 1.2672 - val_accuracy: 0.8860 - lr: 1.3841e-05
# Epoch 98/100
# 26/26 [==============================] - 7s 284ms/step - loss: 1.5405 - accuracy: 0.8616 - val_loss: 1.0598 - val_accuracy: 0.8760 - lr: 1.3841e-05
# Epoch 99/100
# 26/26 [==============================] - 7s 286ms/step - loss: 1.4991 - accuracy: 0.8549 - val_loss: 1.1110 - val_accuracy: 0.8620 - lr: 1.3841e-05
# Epoch 100/100
# 26/26 [==============================] - 7s 284ms/step - loss: 1.4753 - accuracy: 0.8640 - val_loss: 1.0833 - val_accuracy: 0.8880 - lr: 1.3841e-05
# 16/16 [==============================] - 5s 207ms/step - loss: 1.0833 - accuracy: 0.8880
# Test score: 1.0832849740982056
# Test accuracy: 0.8880000710487366

# %%
sns.set_style('darkgrid')

fig, ax = plt.subplots(2, 1, figsize=(20, 10))
df = pd.DataFrame(history_effnetV2B3_noNA_C2D2.history)
df[['loss', 'val_loss']].plot(ax=ax[0])
df[['accuracy', 'val_accuracy']].plot(ax=ax[1])
ax[0].set_title('Model Loss', fontsize=12)
ax[1].set_title('Model Acc', fontsize=12)
fig.suptitle('Model Metrics', fontsize=18)
# Out:
# Text(0.5, 0.98, 'Model Metrics')

# %% [markdown]
# ### Resnet50 with Augmented Data - Transfer Learning

# %%
model_resnet_aug_D2 = Sequential() 
pretrained_model = ResNet50V2(input_shape=(96,96,3), include_top=False, weights='imagenet')
pretrained_model.trainable = True

model_resnet_aug_D2.add(Conv2D(3, kernel_size=(1, 1), activation='relu', padding= 'same'  input_shape=(96, 96, 1)))
model_resnet_aug_D2.add(LeakyReLU(alpha=0.1))
model_resnet_aug_D2.add(pretrained_model)
model_resnet_aug_D2.add(MaxPooling2D(pool_size=(2, 2)))
model_resnet_aug_D2.add(Dropout(0.1))
model_resnet_aug_D2.add(Flatten())
model_resnet_aug_D2.add(Dense(96))
model_resnet_aug_D2.add(Dense(30))


model_resnet_aug_D2.summary()
# Out:
# Metal device set to: Apple M1 Pro
#
# systemMemory: 32.00 GB
# maxCacheSize: 10.67 GB
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 96, 96, 3)         6
#
#  leaky_re_lu (LeakyReLU)     (None, 96, 96, 3)         0
#
#  resnet50v2 (Functional)     (None, 3, 3, 2048)        23564800
#
#  max_pooling2d_3 (MaxPooling  (None, 1, 1, 2048)       0
#  2D)
#
#  dropout (Dropout)           (None, 1, 1, 2048)        0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 96)                196704
#
#  dense_1 (Dense)             (None, 30)                2910
#
# =================================================================
# Total params: 23,764,420
# Trainable params: 23,718,980
# Non-trainable params: 45,440
# _________________________________________________________________

# %%
model_resnet_aug_D2.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])

history_resnet_aug_D2 = model_resnet_aug_D2.fit(train_data_aug, train_labels_aug, batch_size=64, epochs=100, validation_data=(dev_data, dev_labels), shuffle = True, callbacks=[earlyStopping, rlp])
score_resnet_aug_D2 = model_resnet_aug_D2.evaluate(dev_data, dev_labels)
print('Test score:', score_resnet_aug_D2[0]) 
print('Test accuracy:', score_resnet_aug_D2[1])
# Out:
# Epoch 1/100
# 255/255 [==============================] - 57s 213ms/step - loss: 57.4723 - accuracy: 0.6301 - val_loss: 98.7872 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 2/100
# 255/255 [==============================] - 53s 207ms/step - loss: 7.1277 - accuracy: 0.7328 - val_loss: 2.1354 - val_accuracy: 0.8780 - lr: 0.0010
# Epoch 3/100
# 255/255 [==============================] - 53s 208ms/step - loss: 5.3541 - accuracy: 0.7773 - val_loss: 1.4956 - val_accuracy: 0.8760 - lr: 0.0010
# Epoch 4/100
# 255/255 [==============================] - 53s 207ms/step - loss: 4.8141 - accuracy: 0.7993 - val_loss: 2.1634 - val_accuracy: 0.8960 - lr: 0.0010
# Epoch 5/100
# 255/255 [==============================] - 53s 207ms/step - loss: 3.9111 - accuracy: 0.8164 - val_loss: 1.4873 - val_accuracy: 0.9120 - lr: 0.0010
# Epoch 6/100
# 255/255 [==============================] - 53s 207ms/step - loss: 3.4791 - accuracy: 0.8220 - val_loss: 2.0818 - val_accuracy: 0.9360 - lr: 0.0010
# Epoch 7/100
# 255/255 [==============================] - 53s 207ms/step - loss: 3.3151 - accuracy: 0.8327 - val_loss: 4.1199 - val_accuracy: 0.8700 - lr: 0.0010
# Epoch 8/100
# 255/255 [==============================] - 53s 207ms/step - loss: 3.0546 - accuracy: 0.8448 - val_loss: 2.6156 - val_accuracy: 0.9380 - lr: 0.0010
# Epoch
# 255/255 [==============================] - 53s 208ms/step - loss: 1.0461 - accuracy: 0.9199 - val_loss: 0.8223 - val_accuracy: 0.9180 - lr: 1.6807e-04
# Epoch 52/100
# 255/255 [==============================] - ETA: 0s - loss: 1.0672 - accuracy: 0.9185
# Epoch 52: ReduceLROnPlateau reducing learning rate to 0.00011764899536501615.
# 255/255 [==============================] - 53s 208ms/step - loss: 1.0672 - accuracy: 0.9185 - val_loss: 1.0350 - val_accuracy: 0.9000 - lr: 1.6807e-04
# Epoch 53/100
# 255/255 [==============================] - 53s 208ms/step - loss: 0.9720 - accuracy: 0.9236 - val_loss: 0.9262 - val_accuracy: 0.9180 - lr: 1.1765e-04
# Epoch 54/100
# 255/255 [==============================] - 53s 207ms/step - loss: 0.9476 - accuracy: 0.9267 - val_loss: 0.7624 - val_accuracy: 0.9080 - lr: 1.1765e-04
# Epoch 55/100
# 255/255 [==============================] - 53s 208ms/step - loss: 0.9231 - accuracy: 0.9258 - val_loss: 0.7197 - val_accuracy: 0.9120 - lr: 1.1765e-04
# Epoch 56/100
# 255/255 [==============================] - 53s 208ms/step - loss: 0.9178 - accuracy: 0.9275 - val_loss: 0.7314 - val_accuracy: 0.9080 - lr: 1.1765e-04
# Epoch 57/100
# 255/255 [==============================] - ETA: 0s - loss: 0.9474 - accuracy: 0.9254
# Epoch 57: ReduceLROnPlateau reducing learning rate to 8.235429777414538e-05.
# 255/255 [==============================] - 53s 208ms/step - loss: 0.9474 - accuracy: 0.9254 - val_loss: 0.8550 - val_accuracy: 0.9220 - lr: 1.1765e-04
# Epoch 58/100
# 255/255 [==============================] - 53s 207ms/step - loss: 0.8796 - accuracy: 0.9277 - val_loss: 0.7627 - val_accuracy: 0.9160 - lr: 8.2354e-05
# Epoch 59/100
# 255/255 [==============================] - 53s 207ms/step - loss: 0.8545 - accuracy: 0.9318 - val_loss: 0.6989 - val_accuracy: 0.8880 - lr: 8.2354e-05
# Epoch 60/100
# 255/255 [==============================] - 53s 208ms/step - loss: 0.8519 - accuracy: 0.9322 - val_loss: 0.6549 - val_accuracy: 0.9240 - lr: 8.2354e-05
# Epoch 61/100
# 255/255 [==============================] - 53s 208ms/step - loss: 0.8848 - accuracy: 0.9299 - val_loss: 0.6911 - val_accuracy: 0.9100 - lr: 8.2354e-05
# Epoch 62/100
# 255/255 [==============================] - 53s 208ms/step - loss: 0.8600 - accuracy: 0.9295 - val_loss: 0.7167 - val_accuracy: 0.9140 - lr: 8.2354e-05
# Epoch 63/100
# 255/255 [==============================] - 53s 208ms/step - loss: 0.8546 - accuracy: 0.9327 - val_loss: 0.7807 - val_accuracy: 0.9200 - lr: 8.2354e-05
# Epoch 64/100
# 255/255 [==============================] - 53s 207ms/step - loss: 0.8540 - accuracy: 0.9282 - val_loss: 0.6500 - val_accuracy: 0.9200 - lr: 8.2354e-05
# Epoch 65/100
# 255/255 [==============================] - 53s 208ms/step - loss: 0.8524 - accuracy: 0.9280 - val_loss: 0.6768 - val_accuracy: 0.9180 - lr: 8.2354e-05
# Epoch 66/100
# 255/255 [==============================] - 53s 207ms/step - loss: 0.8573 - accuracy: 0.9342 - val_loss: 0.6882 - val_accuracy: 0.9180 - lr: 8.2354e-05
# Epoch 67/100
# 255/255 [==============================] - 53s 208ms/step - loss: 0.8443 - accuracy: 0.9316 - val_loss: 0.6623 - val_accuracy: 0.9220 - lr: 8.2354e-05
# Epoch 68/100
# 255/255 [==============================] - 53s 208ms/step - loss: 0.8473 - accuracy: 0.9341 - val_loss: 0.7047 - val_accuracy: 0.9120 - lr: 8.2354e-05
# Epoch 69/100
# 255/255 [==============================] - ETA: 0s - loss: 0.8283 - accuracy: 0.9325
# Epoch 69: ReduceLROnPlateau reducing learning rate to 5.76480058953166e-05.
# 255/255 [==============================] - 53s 208ms/step - loss: 0.8283 - accuracy: 0.9325 - val_loss: 0.7026 - val_accuracy: 0.9060 - lr: 8.2354e-05
# Epoch 70/100
# 255/255 [==============================] - 53s 208ms/step - loss: 0.8159 - accuracy: 0.9345 - val_loss: 0.6744 - val_accuracy: 0.9280 - lr: 5.7648e-05
# Epoch 71/100
# 255/255 [==============================] - 53s 208ms/step - loss: 0.8038 - accuracy: 0.9328 - val_loss: 0.9987 - val_accuracy: 0.9120 - lr: 5.7648e-05
# Epoch 72/100
# 255/255 [==============================] - 53s 207ms/step - loss: 0.8093 - accuracy: 0.9343 - val_loss: 0.6548 - val_accuracy: 0.9240 - lr: 5.7648e-05
# Epoch 73/100
# 255/255 [==============================] - 53s 208ms/step - loss: 0.7948 - accuracy: 0.9335 - val_loss: 0.7361 - val_accuracy: 0.9140 - lr: 5.7648e-05
# Epoch 74/100
# 255/255 [==============================] - ETA: 0s - loss: 0.7993 - accuracy: 0.9343
# Epoch 74: ReduceLROnPlateau reducing learning rate to 4.0353603617404586e-05.
# 255/255 [==============================] - 54s 211ms/step - loss: 0.7993 - accuracy: 0.9343 - val_loss: 0.7034 - val_accuracy: 0.9160 - lr: 5.7648e-05
# Epoch 75/100
# 255/255 [==============================] - 54s 211ms/step - loss: 0.7843 - accuracy: 0.9369 - val_loss: 0.6931 - val_accuracy: 0.9080 - lr: 4.0354e-05
# Epoch 76/100
# 255/255 [==============================] - 54s 211ms/step - loss: 0.7634 - accuracy: 0.9363 - val_loss: 0.6435 - val_accuracy: 0.9120 - lr: 4.0354e-05
# Epoch 77/100
# 255/255 [==============================] - 54s 211ms/step - loss: 0.7652 - accuracy: 0.9387 - val_loss: 0.6530 - val_accuracy: 0.9220 - lr: 4.0354e-05
# Epoch 78/100
# 255/255 [==============================] - 54s 211ms/step - loss: 0.7591 - accuracy: 0.9365 - val_loss: 0.6622 - val_accuracy: 0.9220 - lr: 4.0354e-05
# Epoch 79/100
# 255/255 [==============================] - 54s 211ms/step - loss: 0.7657 - accuracy: 0.9386 - val_loss: 0.6564 - val_accuracy: 0.9100 - lr: 4.0354e-05
# Epoch 80/100
# 255/255 [==============================] - 54s 210ms/step - loss: 0.7663 - accuracy: 0.9389 - val_loss: 0.7309 - val_accuracy: 0.9200 - lr: 4.0354e-05
# Epoch 81/100
# 255/255 [==============================] - ETA: 0s - loss: 0.7562 - accuracy: 0.9371
# Epoch 81: ReduceLROnPlateau reducing learning rate to 2.8247522277524694e-05.
# 255/255 [==============================] - 54s 211ms/step - loss: 0.7562 - accuracy: 0.9371 - val_loss: 0.6970 - val_accuracy: 0.9100 - lr: 4.0354e-05
# Epoch 82/100
# 255/255 [==============================] - 54s 211ms/step - loss: 0.7414 - accuracy: 0.9387 - val_loss: 0.6395 - val_accuracy: 0.9180 - lr: 2.8248e-05
# Epoch 83/100
# 255/255 [==============================] - 54s 211ms/step - loss: 0.7425 - accuracy: 0.9396 - val_loss: 0.6690 - val_accuracy: 0.9160 - lr: 2.8248e-05
# Epoch 84/100
# 255/255 [==============================] - 54s 212ms/step - loss: 0.7419 - accuracy: 0.9406 - val_loss: 0.6756 - val_accuracy: 0.9080 - lr: 2.8248e-05
# Epoch 85/100
# 255/255 [==============================] - 54s 212ms/step - loss: 0.7420 - accuracy: 0.9407 - val_loss: 0.8235 - val_accuracy: 0.9200 - lr: 2.8248e-05
# Epoch 86/100
# 255/255 [==============================] - 54s 211ms/step - loss: 0.7433 - accuracy: 0.9388 - val_loss: 0.7631 - val_accuracy: 0.9200 - lr: 2.8248e-05
# Epoch 87/100
# 255/255 [==============================] - ETA: 0s - loss: 0.7337 - accuracy: 0.9413
# Epoch 87: ReduceLROnPlateau reducing learning rate to 1.977326610358432e-05.
# 255/255 [==============================] - 54s 211ms/step - loss: 0.7337 - accuracy: 0.9413 - val_loss: 0.6464 - val_accuracy: 0.9140 - lr: 2.8248e-05
# Epoch 88/100
# 255/255 [==============================] - 54s 212ms/step - loss: 0.7274 - accuracy: 0.9390 - val_loss: 0.6447 - val_accuracy: 0.9140 - lr: 1.9773e-05
# Epoch 89/100
# 255/255 [==============================] - 54s 211ms/step - loss: 0.7194 - accuracy: 0.9406 - val_loss: 0.6510 - val_accuracy: 0.9220 - lr: 1.9773e-05
# Epoch 90/100
# 255/255 [==============================] - 54s 211ms/step - loss: 0.7264 - accuracy: 0.9411 - val_loss: 0.6552 - val_accuracy: 0.9180 - lr: 1.9773e-05
# Epoch 91/100
# 255/255 [==============================] - 54s 211ms/step - loss: 0.7243 - accuracy: 0.9417 - val_loss: 0.6516 - val_accuracy: 0.9160 - lr: 1.9773e-05
# Epoch 92/100
# 255/255 [==============================] - ETA: 0s - loss: 0.7203 - accuracy: 0.9416
# Epoch 92: ReduceLROnPlateau reducing learning rate to 1.3841286272509023e-05.
# 255/255 [==============================] - 54s 211ms/step - loss: 0.7203 - accuracy: 0.9416 - val_loss: 0.6585 - val_accuracy: 0.9240 - lr: 1.9773e-05
# Epoch 93/100
# 255/255 [==============================] - 54s 211ms/step - loss: 0.7211 - accuracy: 0.9407 - val_loss: 0.6401 - val_accuracy: 0.9180 - lr: 1.3841e-05
# Epoch 94/100
# 255/255 [==============================] - 54s 211ms/step - loss: 0.7108 - accuracy: 0.9427 - val_loss: 0.6509 - val_accuracy: 0.9200 - lr: 1.3841e-05
# Epoch 95/100
# 255/255 [==============================] - 54s 211ms/step - loss: 0.7154 - accuracy: 0.9440 - val_loss: 0.6363 - val_accuracy: 0.9180 - lr: 1.3841e-05
# Epoch 96/100
# 255/255 [==============================] - 54s 211ms/step - loss: 0.7074 - accuracy: 0.9425 - val_loss: 0.7108 - val_accuracy: 0.9140 - lr: 1.3841e-05
# Epoch 97/100
# 255/255 [==============================] - 54s 211ms/step - loss: 0.7038 - accuracy: 0.9421 - val_loss: 0.6906 - val_accuracy: 0.9140 - lr: 1.3841e-05
# Epoch 98/100
# 255/255 [==============================] - 54s 211ms/step - loss: 0.7129 - accuracy: 0.9393 - val_loss: 0.6373 - val_accuracy: 0.9140 - lr: 1.3841e-05
# Epoch 99/100
# 255/255 [==============================] - 54s 211ms/step - loss: 0.7044 - accuracy: 0.9411 - val_loss: 0.6537 - val_accuracy: 0.9140 - lr: 1.3841e-05
# Epoch 100/100
# 255/255 [==============================] - ETA: 0s - loss: 0.7099 - accuracy: 0.9426
# Epoch 100: ReduceLROnPlateau reducing learning rate to 9.688900263427058e-06.
# 255/255 [==============================] - 54s 211ms/step - loss: 0.7099 - accuracy: 0.9426 - val_loss: 0.6564 - val_accuracy: 0.9180 - lr: 1.3841e-05
# 16/16 [==============================] - 1s 47ms/step - loss: 0.6564 - accuracy: 0.9180
# Test score: 0.6563727259635925
# Test accuracy: 0.9180000424385071

# %%
sns.set_style('darkgrid')

fig, ax = plt.subplots(2, 1, figsize=(20, 10))
df = pd.DataFrame(history_resnet_aug_D2.history)
df[['loss', 'val_loss']].plot(ax=ax[0])
df[['accuracy', 'val_accuracy']].plot(ax=ax[1])
ax[0].set_title('Model Loss', fontsize=12)
ax[1].set_title('Model Acc', fontsize=12)
fig.suptitle('Model Metrics', fontsize=18)
# Out:
# Text(0.5, 0.98, 'Model Metrics')

# %% [markdown]
# ### Efficientnet with Augmented data

# %%
model_effnetB7_aug_D2 = Sequential() 
pretrained_model = EfficientNetB7(input_shape= (96, 96, 3), include_top= False, weights='imagenet')
pretrained_model.trainable = True

model_effnetB7_aug_D2.add(Conv2D(3, kernel_size=(1, 1), activation='relu', padding= 'same' ,input_shape=(96, 96, 1)))
model_effnetB7_aug_D2.add(LeakyReLU(alpha=0.1))
model_effnetB7_aug_D2.add(pretrained_model)
model_effnetB7_aug_D2.add(MaxPooling2D(pool_size=(2, 2)))
model_effnetB7_aug_D2.add(Dropout(0.1))
model_effnetB7_aug_D2.add(Flatten())
model_effnetB7_aug_D2.add(Dense(30))


model_effnetB7_aug_D2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 96, 96, 3)         6
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 96, 96, 3)         0
#
#  efficientnetb7 (Functional)  (None, 3, 3, 2560)       64097687
#
#  max_pooling2d_5 (MaxPooling  (None, 1, 1, 2560)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 1, 1, 2560)        0
#
#  flatten_2 (Flatten)         (None, 2560)              0
#
#  dense_3 (Dense)             (None, 30)                76830
#
# =================================================================
# Total params: 64,174,523
# Trainable params: 63,863,796
# Non-trainable params: 310,727
# _________________________________________________________________

# %%
model_effnetB7_aug_D2.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])

history_effnetB7_aug_D2 = model_effnetB7_aug_D2.fit(train_data_aug, train_labels_aug, batch_size=64, epochs=100, validation_data=(dev_data, dev_labels), shuffle = True, callbacks=[earlyStopping, rlp])
score_effnetB7_aug_D2 = model_effnetB7_aug_D2.evaluate(dev_data, dev_labels)
print('Test score:', score_effnetB7_aug_D2[0]) 
print('Test accuracy:', score_effnetB7_aug_D2[1])
# Out:
# Epoch 1/100
# 255/255 [==============================] - 314s 1s/step - loss: 53.2580 - accuracy: 0.6419 - val_loss: 61.5373 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 2/100
# 255/255 [==============================] - 20502s 81s/step - loss: 7.0874 - accuracy: 0.7191 - val_loss: 47.8087 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 3/100
# 255/255 [==============================] - 10703s 42s/step - loss: 5.7972 - accuracy: 0.7551 - val_loss: 8.0438 - val_accuracy: 0.8440 - lr: 0.0010
# Epoch 4/100
# 197/255 [======================>.......] - ETA: 27:38 - loss: 4.2508 - accuracy: 0.7846
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/acarite/Desktop/MIDS/w207/mids_w207_final_project/alex_dev_notebook.ipynb Cell 28' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/acarite/Desktop/MIDS/w207/mids_w207_final_project/alex_dev_notebook.ipynb#ch0000027?line=0'>1</a> model_effnetB7_aug_D2.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])
# ----> <a href='vscode-notebook-cell:/Users/acarite/Desktop/MIDS/w207/mids_w207_final_project/alex_dev_notebook.ipynb#ch0000027?line=2'>3</a> history_effnetB7_aug_D2 = model_effnetB7_aug_D2.fit(train_data_aug, train_labels_aug, batch_size=64, epochs=100, validation_data=(dev_data, dev_labels), shuffle = True, callbacks=[earlyStopping, rlp])
#       <a href='vscode-notebook-cell:/Users/acarite/Desktop/MIDS/w207/mids_w207_final_project/alex_dev_notebook.ipynb#ch0000027?line=3'>4</a> score_effnetB7_aug_D2 = model_effnetB7_aug_D2.evaluate(dev_data, dev_labels)
#       <a href='vscode-notebook-cell:/Users/acarite/Desktop/MIDS/w207/mids_w207_final_project/alex_dev_notebook.ipynb#ch0000027?line=4'>5</a> print('Test score:', score_effnetB7_aug_D2[0])
#
# File ~/miniforge3/envs/deeplearn/lib/python3.8/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/keras/utils/traceback_utils.py?line=61'>62</a> filtered_tb = None
#      <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/keras/utils/traceback_utils.py?line=62'>63</a> try:
# ---> <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/keras/utils/traceback_utils.py?line=63'>64</a>   return fn(*args, **kwargs)
#      <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/keras/utils/traceback_utils.py?line=64'>65</a> except Exception as e:  # pylint: disable=broad-except
#      <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/keras/utils/traceback_utils.py?line=65'>66</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniforge3/envs/deeplearn/lib/python3.8/site-packages/keras/engine/training.py:1384, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/keras/engine/training.py?line=1376'>1377</a> with tf.profiler.experimental.Trace(
#    <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/keras/engine/training.py?line=1377'>1378</a>     'train',
#    <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/keras/engine/training.py?line=1378'>1379</a>     epoch_num=epoch,
#    <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/keras/engine/training.py?line=1379'>1380</a>     step_num=step,
#    <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/keras/engine/training.py?line=1380'>1381</a>     batch_size=batch_size,
#    <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/keras/engine/training.py?line=1381'>1382</a>     _r=1):
#    <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/keras/engine/training.py?line=1382'>1383</a>   callbacks.on_train_batch_begin(step)
# -> <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/keras/engine/training.py?line=1383'>1384</a>   tmp_logs = self.train_function(iterator)
#    <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/keras/engine/training.py?line=1384'>1385</a>   if data_handler.should_sync:
#    <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/keras/engine/training.py?line=1385'>1386</a>     context.async_wait()
#
# File ~/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py?line=147'>148</a> filtered_tb = None
#     <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py?line=148'>149</a> try:
# --> <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py?line=149'>150</a>   return fn(*args, **kwargs)
#     <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py?line=150'>151</a> except Exception as e:
#     <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py?line=151'>152</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py?line=911'>912</a> compiler = "xla" if self._jit_compile else "nonXla"
#     <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py?line=913'>914</a> with OptionalXlaContext(self._jit_compile):
# --> <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py?line=914'>915</a>   result = self._call(*args, **kwds)
#     <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py?line=916'>917</a> new_tracing_count = self.experimental_get_tracing_count()
#     <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py?line=917'>918</a> without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py?line=943'>944</a>   self._lock.release()
#     <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py?line=944'>945</a>   # In this case we have created variables on the first call, so we run the
#     <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py?line=945'>946</a>   # defunned version which is guaranteed to never create variables.
# --> <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py?line=946'>947</a>   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py?line=947'>948</a> elif self._stateful_fn is not None:
#     <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py?line=948'>949</a>   # Release the lock early so that multiple threads can perform the call
#     <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py?line=949'>950</a>   # in parallel.
#     <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py?line=950'>951</a>   self._lock.release()
#
# File ~/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/function.py:2956, in Function.__call__(self, *args, **kwargs)
#    <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=2952'>2953</a> with self._lock:
#    <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=2953'>2954</a>   (graph_function,
#    <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=2954'>2955</a>    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=2955'>2956</a> return graph_function._call_flat(
#    <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=2956'>2957</a>     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/function.py:1853, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1848'>1849</a> possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1849'>1850</a> if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1850'>1851</a>     and executing_eagerly):
#    <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1851'>1852</a>   # No tape is watching; skip to running the function.
# -> <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1852'>1853</a>   return self._build_call_outputs(self._inference_function.call(
#    <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1853'>1854</a>       ctx, args, cancellation_manager=cancellation_manager))
#    <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1854'>1855</a> forward_backward = self._select_forward_and_backward_functions(
#    <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1855'>1856</a>     args,
#    <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1856'>1857</a>     possible_gradient_type,
#    <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1857'>1858</a>     executing_eagerly)
#    <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=1858'>1859</a> forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=496'>497</a> with _InterpolateFunctionError(self):
#     <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=497'>498</a>   if cancellation_manager is None:
# --> <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=498'>499</a>     outputs = execute.execute(
#     <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=499'>500</a>         str(self.signature.name),
#     <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=500'>501</a>         num_outputs=self._num_outputs,
#     <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=501'>502</a>         inputs=args,
#     <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=502'>503</a>         attrs=attrs,
#     <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=503'>504</a>         ctx=ctx)
#     <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=504'>505</a>   else:
#     <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=505'>506</a>     outputs = execute.execute_with_cancellation(
#     <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=506'>507</a>         str(self.signature.name),
#     <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=507'>508</a>         num_outputs=self._num_outputs,
#    (...)
#     <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=510'>511</a>         ctx=ctx,
#     <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/function.py?line=511'>512</a>         cancellation_manager=cancellation_manager)
#
# File ~/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/execute.py?line=51'>52</a> try:
#      <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/execute.py?line=52'>53</a>   ctx.ensure_initialized()
# ---> <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/execute.py?line=53'>54</a>   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/execute.py?line=54'>55</a>                                       inputs, attrs, num_outputs)
#      <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/execute.py?line=55'>56</a> except core._NotOkStatusException as e:
#      <a href='file:///Users/acarite/miniforge3/envs/deeplearn/lib/python3.8/site-packages/tensorflow/python/eager/execute.py?line=56'>57</a>   if name is not None:
#
# KeyboardInterrupt:

# %%
sns.set_style('darkgrid')

fig, ax = plt.subplots(2, 1, figsize=(20, 10))
df = pd.DataFrame(history_effnetB7_aug_D2.history)
df[['loss', 'val_loss']].plot(ax=ax[0])
df[['accuracy', 'val_accuracy']].plot(ax=ax[1])
ax[0].set_title('Model Loss', fontsize=12)
ax[1].set_title('Model Acc', fontsize=12)
fig.suptitle('Model Metrics', fontsize=18)
# Out:
# Text(0.5, 0.98, 'Model Metrics')

# %% [markdown]
# ### Jeff Heaton Transfer Learning Method

# %%
train_ds = train_data_aug.cache().batch(32).prefetch(buffer_size=10)
dev_ds = dev_data.cache().batch(32).prefetch(buffer_size=10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [79], in <cell line: 1>()
# ----> 1 train_ds = train_data_aug.cache().batch(32).prefetch(buffer_size=10)
#       2 dev_ds = dev_data.cache().batch(32).prefetch(buffer_size=10)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'cache'

# %% [markdown]
# ## Creating Submission

# %%
id_lookup = pd.read_csv('IdLookupTable.csv')

ImageId = list(id_lookup['ImageId']-1)
RowId = list(id_lookup['RowId'])
FeatureName = list(id_lookup['FeatureName'])
feature_list = []
for feature in FeatureName:
    feature_list.append(FeatureName.index(feature))

# %%
def submit(model, test_data, model_name):
    #RowId,ImageId,FeatureName,Location
    #Make Predictions 
    y_pred = model.predict(test_data)

    predictions = []
    for x,y in zip(ImageId, feature_list):
        predictions.append(y_pred[x][y])
        
    row_ids = pd.Series(RowId, name = 'RowId')
    locations = pd.Series(predictions, name = 'Location')
    
    #post processing step 
    locations = locations.clip(0.0,96.0)
    submission_result = pd.concat([row_ids,locations],axis = 1)
    submission_result.to_csv(f'{model_name}',index = False)

# %%
submit(model_resnet_aug_D2, test_images, 'resnet_1')
